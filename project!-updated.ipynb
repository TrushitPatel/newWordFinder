# %% [markdown]
# ## read inputDataFile of a string containg  subtitle

# %%
inputFile="/home/sarkijatru/Desktop/documentry_Saturday/Naked Science - Birth of the Universe.srt"
with open (inputFile, "r") as myfile:
    data=myfile.read()
myfile.close()
data
# Out:
# '1\n00:00:00,890 --> 00:00:02,029\n[Music]\n\n2\n00:00:02,029 --> 00:00:06,120\nour<font color="#E5E5E5"> universe the galaxies the solar</font>\n\n3\n00:00:06,120 --> 00:00:09,920\nsystem our home planet Earth\n\n4\n00:00:09,920 --> 00:00:14,750\nland sea air life where did<font color="#CCCCCC"> they all</font>\n\n5\n00:00:14,750 --> 00:00:17,450\ncome from look up into<font color="#E5E5E5"> space from our</font>\n\n6\n00:00:17,450 --> 00:00:20,720\n<font color="#E5E5E5">planet and what you see is a vast cosmos</font>\n\n7\n00:00:20,720 --> 00:00:23,360\nteeming with billions of stars and\n\n8\n00:00:23,360 --> 00:00:26,810\n<font color="#CCCCCC">galaxies turn back</font><font color="#E5E5E5"> the clock over 13</font>\n\n9\n00:00:26,810 --> 00:00:29,539\nbillion years<font color="#E5E5E5"> and our universe was a</font>\n\n10\n00:00:29,539 --> 00:00:32,360\nvery different<font color="#CCCCCC"> place back then it was so</font>\n\n11\n00:00:32,360 --> 00:00:34,790\n<font color="#CCCCCC">small but it could fit inside the palm</font>\n\n12\n00:00:34,790 --> 00:00:40,030\n<font color="#CCCCCC">of your hand from this infant universe</font>\n\n13\n00:00:40,030 --> 00:00:42,699\n<font color="#E5E5E5">everything would be created stars</font>\n\n14\n00:00:42,699 --> 00:00:45,620\ngalaxies<font color="#CCCCCC"> and the building blocks of life</font>\n\n15\n00:00:45,620 --> 00:00:49,159\nitself the calcium in our<font color="#E5E5E5"> bones the iron</font>\n\n16\n00:00:49,159 --> 00:00:51,630\nin our blood\n\n17\n00:00:51,630 --> 00:00:54,230\nthe atoms for the air we breathe the\n\n18\n00:00:54,230 --> 00:00:57,420\nwater<font color="#CCCCCC"> we drink</font>\n\n19\n00:00:57,420 --> 00:01:00,710\nthe raw materials for<font color="#CCCCCC"> our cities and</font>\n\n20\n00:01:00,710 --> 00:01:03,710\nmachines\n\n21\n00:01:04,409 --> 00:01:06,869\nnaked science takes a journey<font color="#E5E5E5"> through</font>\n\n22\n00:01:06,869 --> 00:01:09,359\nspace and<font color="#CCCCCC"> time to discover how</font><font color="#E5E5E5"> the</font>\n\n23\n00:01:09,359 --> 00:01:12,899\nuniverse was<font color="#E5E5E5"> born and how it created</font>\n\n24\n00:01:12,899 --> 00:01:15,740\neverything in<font color="#E5E5E5"> our world</font>\n\n25\n00:01:15,740 --> 00:01:20,409\nand how eventually it will die\n\n26\n00:01:37,570 --> 00:01:40,700\neverything we see around us is made of\n\n27\n00:01:40,700 --> 00:01:44,840\nmatter atoms and molecules take this car\n\n28\n00:01:44,840 --> 00:01:48,670\nit\'s a 1956 ford fairlane convertible\n\n29\n00:01:48,670 --> 00:01:51,049\nit\'s constructed from many different\n\n30\n00:01:51,049 --> 00:01:56,420\nmaterials<font color="#E5E5E5"> like steel rubber and glass go</font>\n\n31\n00:01:56,420 --> 00:01:58,819\ndeeper and these materials are made up\n\n32\n00:01:58,819 --> 00:02:01,149\nfrom combinations of elements like iron\n\n33\n00:02:01,149 --> 00:02:05,360\nsilicon chromium and carbon each and\n\n34\n00:02:05,360 --> 00:02:08,090\n<font color="#E5E5E5">every atom that makes up this car were</font>\n\n35\n00:02:08,090 --> 00:02:11,709\ncreated by our growing universe\n\n36\n00:02:12,579 --> 00:02:15,590\nphysicist Lawrence Krauss studies how\n\n37\n00:02:15,590 --> 00:02:18,019\nthe atoms we see on our planet have come\n\n38\n00:02:18,019 --> 00:02:21,410\nto be<font color="#CCCCCC"> here we really are parts Stardust</font>\n\n39\n00:02:21,410 --> 00:02:24,530\nand part Big Bang dusk most of the atoms\n\n40\n00:02:24,530 --> 00:02:26,209\n<font color="#E5E5E5">in our body are from the cores of stars</font>\n\n41\n00:02:26,209 --> 00:02:28,280\nbut<font color="#E5E5E5"> some of them have been around since</font>\n\n42\n00:02:28,280 --> 00:02:30,500\n<font color="#E5E5E5">the earliest moments of the Big Bang so</font>\n\n43\n00:02:30,500 --> 00:02:33,670\nwe really<font color="#E5E5E5"> are truly cosmic individuals</font>\n\n44\n00:02:33,670 --> 00:02:36,250\neach<font color="#E5E5E5"> and every atom w ...

# %% [markdown]
# ### remove other than subtitles

# %%
import re

data = re.sub("\d+|:|,|-->|\n|<.*?>|'s", "", data)
data = re.sub("-", " ", data)
len(data)
# Out:
# 37623

# %% [markdown]
# ## convert data into word form and remove duplicates

# %%
from nltk import sent_tokenize, word_tokenize

data = list(map(str.lower, word_tokenize(data)))
newData=set()
for i in data:
    newData.add(i)
#data contains words of subtitle and it's a set    
data=set()
data=newData
print(data,len(data))
# Out:
# {'saw', 'bonds', 'turmoil', 'glowing', 'ever', 'send', 'cosmos', 'seen', 'code', 'carbon', 'world', 'conclude', 'side', 'test', 'sort', 'studies', 'said', 'temperatures', 'penzias', 'heavier', 'zero', 'david', 'makes', 'make', 'gravity', 'party', 'other', 'cars', 'todd', 'vehicle', 'ones', 'collapsed', 'edwin', 'skies', 'left', 'degrees', 'mars', 'destabilizes', 'serious', 'entire', 'electron', 'helping', 'ca', 'whimper', 'densities', 'measured', 'always', 'dwarfs', 'wind', 'kate', 'created', 'combinations', 'fireworks', 'frank', 'made', 'none', 'growing', 'results', 'desperation', 'outward', 'thinking', 'scientific', 'nuclear', 'density', 'fusion', 'automobiles', 'precisely', 'listes', 'physics', 'lifeless', 'slight', 'bit', 'pigeons', 'probe', 'suddenly', 'others', 'pull', 'identify', 'convinced', 'birthday', 'finite', 'below', 'officially', 'cruel', 'quiet', 'acted', 'could', 'gotten', 'special', 'positions', 'tony', 'millions', 'creation', 'once', 'visible', 'knows', 'dawn', 'spectrum', 'biblical', 'examining', 'fluctuations', 'wake', 'bloated', 'designed', 'proper', 'champagne', 'old', 'percent', 'shoulder', 'coming', 'ripped', 'material', 'naked', 'race', 'down', 'own', 'beads', 'oak', 'astounding', 'believe', 'something', 'electrons', 'steel', 'leave', 'filled', 'released', 'hundreds', 'massive', 'nearly', 'elements', 'leftover', 'shower', 'enormous', 'appear', 'trillions', 'crumples', 'gave', 'characteristic', 'speeds', 'incredibly', 'clusters', 'young', 'taking', 'derision', 'extra', 'despite', 'towards', 'hurtled', 'cheesy', 'spurt', 'becomes', 'fog', 'emerged', 'than', 'quite', 'galaxy', 'starts', 'need', 'map', 'disk', 'days', 'go', 'cosmic', 'atoms', 'filaments', 'live', 'out', 'mailed', 'bomb', 'explains', 'inter', 'suggests', 'centimeter', 'things', 'dreams', 'touch', 'starting', 'tools', 'foggy', 'arno', 'resolute', 'hilton', 'lift', 'mass', 'works', 'cells', 'known', 'nearby', 'grown', 'deeper', 'exist', 'talk', 'unexpected', 'did', 'speeding', 'and', 'subatomic', 'extremely', 'appears', 'containing', 'color', 'successively', 'be', 'account', 'lydman', 'basic', 'noise', 'tuned', 'mysterious', 'carlos', 'cool', 'objects', 'galaxies', 'neutrons', 'molecules', 'off', 'vlt', 'give', 'worst', 'time', 'added', 'genesis', 'wrinkle', 'them', 'thousand', 'lamp', 'rang', 'globs', 'fender', 'astrophysicist', 'smashing', 'continued', 'ending', 'ran', 'there', 'site', 'individual', 'trees', 'cameras', 'hotter', 'unstable', 'heaviest', 'do', 'ridge', 'mother', 'shriveled', 'assembly', 'shrapnel', 'temperature', 'variations', 'gas', 'bind', 'does', 'an', 'archrival', 'voids', 'perfectly', 'convertible', 'emits', 'experimental', 'calm', 'heavy', 'big', 'making', 'fingerprint', 'place', 'both', 'reactors', 'nasa', 'moment', 'andromeda', 'enter', 'chapter', 'generated', 'inescapable', 'think', 'crew', 'expensive', 'distances', 'flowed', 'dust', 'tire', 'history', 'conjures', 'exploded', 'collide', 'who', 'bright', 'variation', 'droppings', 'breathe', 'spiral', 'links', 'earth', 'except', 'try', 'amounts', 'plants', 'breath', 'halt', 'end', 'missing', 'the', 'rash', 'clues', 'system', 'was', 'pens', 'step', 'stiff', 'recent', 'smaller', 'uniform', 'bounces', 'into', 'distorted', 'telescope', 'michael', 'atomic', 'mission', 'is', 'slowly', 'held', 'tiny', 'located', 'materials', 'blood', 'applause', 'together', 'granted', 'tend', 'richer', 'five', 'body', 'then', 'two', 'dense', 'explodes', 'are', 'heard', 'which', 'astronauts', 'jigsaw', 'war', 'different', 'companion', 'nightmare', 'generates', 'year', 'burn', 'constructed', 'grabbed', 'conclusion', 'building', 'job', 'amount', 'lives', 'detail', 'east', 'she', 'day', 'equally', 'thirty', 'over', 'even', 'all', 'beyond', 'eventually', 'greatest', 'creative', 'expanded', 'just', 'solar', 'never', 'unravel', 'lifted', 'led', 'phase', 'shock', 'eons', 'restarts', 'amazing', 'specific', 'times', 'create', 'built', 'rapid', 'part', 'called', 'island', 'fahrenheit', 'removing', 'reve ...

# %% [markdown]
# ### remove stopWords and punctuations

# %%
from nltk.corpus import stopwords
from string import punctuation
#toBeRemoved contains words that are stopwords and punctuations that we want to remove from data
toBeRemoved = set(stopwords.words('english'))
toBeRemoved = toBeRemoved.union(set(punctuation))
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %% [markdown]
# ### more words to remove as stopWords

# %%
stopwords_json = {"en":["a","n't","'re'","'ve'","a's","able","about","above","according","accordingly","across","actually","after","afterwards","again","against","ain't","all","allow","allows","almost","alone","along","already","also","although","always","am","among","amongst","an","and","another","any","anybody","anyhow","anyone","anything","anyway","anyways","anywhere","apart","appear","appreciate","appropriate","are","aren't","around","as","aside","ask","asking","associated","at","available","away","awfully","b","be","became","because","become","becomes","becoming","been","before","beforehand","behind","being","believe","below","beside","besides","best","better","between","beyond","both","brief","but","by","c","c'mon","c's","came","can","can't","cannot","cant","cause","causes","certain","certainly","changes","clearly","co","com","come","comes","concerning","consequently","consider","considering","contain","containing","contains","corresponding","could","couldn't","course","currently","d","definitely","described","despite","did","didn't","different","do","does","doesn't","doing","don't","done","down","downwards","during","e","each","edu","eg","eight","either","else","elsewhere","enough","entirely","especially","et","etc","even","ever","every","everybody","everyone","everything","everywhere","ex","exactly","example","except","f","far","few","fifth","first","five","followed","following","follows","for","former","formerly","forth","four","from","further","furthermore","g","get","gets","getting","given","gives","go","goes","going","gone","got","gotten","greetings","h","had","hadn't","happens","hardly","has","hasn't","have","haven't","having","he","he's","hello","help","hence","her","here","here's","hereafter","hereby","herein","hereupon","hers","herself","hi","him","himself","his","hither","hopefully","how","howbeit","however","i","i'd","i'll","i'm","i've","ie","if","ignored","immediate","in","inasmuch","inc","indeed","indicate","indicated","indicates","inner","insofar","instead","into","inward","is","isn't","it","it'd","it'll","it's","its","itself","j","just","k","keep","keeps","kept","know","known","knows","l","last","lately","later","latter","latterly","least","less","lest","let","let's","like","liked","likely","little","look","looking","looks","ltd","m","mainly","many","may","maybe","me","mean","meanwhile","merely","might","more","moreover","most","mostly","much","must","my","myself","n","name","namely","nd","near","nearly","necessary","need","needs","neither","never","nevertheless","new","next","nine","no","nobody","non","none","noone","nor","normally","not","nothing","novel","now","nowhere","o","obviously","of","off","often","oh","ok","okay","old","on","once","one","ones","only","onto","or","other","others","otherwise","ought","our","ours","ourselves","out","outside","over","overall","own","p","particular","particularly","per","perhaps","placed","please","plus","possible","presumably","probably","provides","q","que","quite","qv","r","rather","rd","re","really","reasonably","regarding","regardless","regards","relatively","respectively","right","s","said","same","saw","say","saying","says","second","secondly","see","seeing","seem","seemed","seeming","seems","seen","self","selves","sensible","sent","serious","seriously","seven","several","shall","she","should","shouldn't","since","six","so","some","somebody","somehow","someone","something","sometime","sometimes","somewhat","somewhere","soon","sorry","specified","specify","specifying","still","sub","such","sup","sure","t","t's","take","taken","tell","tends","th","than","thank","thanks","thanx","that","that's","thats","the","their","theirs","them","themselves","then","thence","there","there's","thereafter","thereby","therefore","therein","theres","thereupon","these","they","they'd","they'll","they're","they've","think","third","this","thorough","thoroughly","those","though","three","through","throughout","thru","thus","to","together","too","took","toward","towards","tried","tries","truly","try","trying","twice","two","u","un","under","unfortunately","unless","unlikely","until","unto","up","upon","us","use","used","useful","uses","using","usually","uucp","v","value","various","very","via","viz","vs","w","want","wants","was","wasn't","way","we","we'd","we'll","we're","we've","welcome","well","went","were","weren't","what","what's","whatever","when","whence","whenever","where","where's","whereafter","whereas","whereby","wherein","whereupon","wherever","whether","which","while","whither","who","who's","whoever","whole","whom","whose","why","will","willing","wish","with","within","without","won't","wonder","would","wouldn't","x","y","yes","yet","you","you'd","you'll","you're","you've","your","yours","yourself","yourselves","z","zero"]}
toBeRemoved = toBeRemoved.union(set(stopwords_json['en']))
toBeRemoved
# Out:
# {'!',
#  '"',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  "'re'",
#  "'ve'",
#  '(',
#  ')',
#  '*',
#  '+',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  ';',
#  '<',
#  '=',
#  '>',
#  '?',
#  '@',
#  '[',
#  '\\',
#  ']',
#  '^',
#  '_',
#  '`',
#  'a',
#  "a's",
#  'able',
#  'about',
#  'above',
#  'according',
#  'accordingly',
#  'across',
#  'actually',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'ain',
#  "ain't",
#  'all',
#  'allow',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'apart',
#  'appear',
#  'appreciate',
#  'appropriate',
#  'are',
#  'aren',
#  "aren't",
#  'around',
#  'as',
#  'aside',
#  'ask',
#  'asking',
#  'associated',
#  'at',
#  'available',
#  'away',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'believe',
#  'below',
#  'beside',
#  'besides',
#  'best',
#  'better',
#  'between',
#  'beyond',
#  'both',
#  'brief',
#  'but',
#  'by',
#  'c',
#  "c'mon",
#  "c's",
#  'came',
#  'can',
#  "can't",
#  'cannot',
#  'cant',
#  'cause',
#  'causes',
#  'certain',
#  'certainly',
#  'changes',
#  'clearly',
#  'co',
#  'com',
#  'come',
#  'comes',
#  'concerning',
#  'consequently',
#  'consider',
#  'considering',
#  'contain',
#  'containing',
#  'contains',
#  'corresponding',
#  'could',
#  'couldn',
#  "couldn't",
#  'course',
#  'currently',
#  'd',
#  'definitely',
#  'described',
#  'despite',
#  'did',
#  'didn',
#  "didn't",
#  'different',
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'done',
#  'down',
#  'downwards',
#  'during',
#  'e',
#  'each',
#  'edu',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'entirely',
#  'especially',
#  'et',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'exactly',
#  'example',
#  'except',
#  'f',
#  'far',
#  'few',
#  'fifth',
#  'first',
#  'five',
#  'followed',
#  'following',
#  'follows',
#  'for',
#  'former',
#  'formerly',
#  'forth',
#  'four',
#  'from',
#  'further',
#  'furthermore',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'given',
#  'gives',
#  'go',
#  'goes',
#  'going',
#  'gone',
#  'got',
#  'gotten',
#  'greetings',
#  'h',
#  'had',
#  'hadn',
#  "hadn't",
#  'happens',
#  'hardly',
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he's",
#  'hello',
#  'help',
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hi',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hopefully',
#  'how',
#  'howbeit',
#  'however',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'ie',
#  'if',
#  'ignored',
#  'immediate',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'inner',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'keep',
#  'keeps',
#  'kept',
#  'know',
#  'known',
#  'knows',
#  'l',
#  'last',
#  'lately',
#  'later',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'lest',
#  'let',
#  "let's",
#  'like',
#  'liked',
#  'likely',
#  'little',
#  'll',
#  'look',
#  'looking',
#  'looks',
#  'ltd',
#  'm',
#  'ma',
#  'mainly',
#  'many',
#  'may',
#  'maybe',
#  'me',
#  'mean',
#  'meanwhile',
#  'merely',
#  'might',
#  'mightn',
#  "mightn't",
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'must',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'n',
#  "n't",
#  'name',
#  'namely',
#  'nd',
#  'near',
#  'nearly',
#  'necessary',
#  'need',
#  'needn',
#  "needn't",
#  'needs',
#  'neither',
#  'never',
#  'nevertheless',
#  'new',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'non',
#  'none',
#  'noone',
#  'nor',
#  'normally',
#  'not',
#  'nothing',
#  'novel',
#  'now',
#  'nowhere',
#  'o',
#  'obviously',
#  'of',
#  'off',
#  'often',
#  'oh',
#  'ok',
#  'okay',
#  'old',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'outside',
#  'over',
#  'overall',
#  'own',
#  'p',
#  'particular',
#  'particularly',
#  'per',
#  'perhaps',
#  'placed',
#  'please',
#  'plus',
#  'possible',
#  'presumably',
#  'probably',
#  'provides',
#  'q',
#  'que',
#  'quite',
#  'qv',
#  'r',
#  'rather',
#  'rd',
#  're',
#  'really',
#  'reasonably',
#  'regarding',
#  'regardless',
#  'regards',
#  'relatively',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'same',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'second',
#  'secondly',
#  'see',
#  'seeing',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'seen',
#  'self',
#  'selves',
#  'sensible',
#  'sent',
#  'serious',
#  'seriously',
#  'seven',
#  'several',
#  'shall',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'since',
#  'six',
#  'so',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhat',
#  'somewhere',
#  'soon',
#  'sorry',
#  'specified',
#  'specify',
#  'specifying',
#  'still',
#  'sub',
#  'such',
#  'sup',
#  'sure',
#  't',
#  "t's",
#  'take',
#  'taken',
#  'tell',
#  'tends',
#  'th',
#  'than',
#  'thank',
#  'thanks',
#  'thanx',
#  'that',
#  "that'll",
#  "that's",
#  'thats',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  "there's",
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'theres',
#  'thereupon',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'think',
#  'third',
#  'this',
#  'thorough',
#  'thoroughly',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'took',
#  'toward',
#  'towards',
#  'tried',
#  'tries',
#  'truly',
#  'try',
#  'trying',
#  'twice',
#  'two',
#  'u',
#  'un',
#  'under',
#  'unfortunately',
#  'unless',
#  'unlikely',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'useful',
#  'uses',
#  'using',
#  'usually',
#  'uucp',
#  'v',
#  'value',
#  'various',
#  've',
#  'very',
#  'via',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'wants',
#  'was',
#  'wasn',
#  "wasn't",
#  'way',
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'welcome',
#  'well',
#  'went',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  "what's",
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  "where's",
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  "who's",
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'willing',
#  'wish',
#  'with',
#  'within',
#  'without',
#  'won',
#  "won't",
#  'wonder',
#  'would',
#  'wouldn',
#  "wouldn't",
#  'x',
#  'y',
#  'yes',
#  'yet',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zero',
#  '{',
#  '|',
#  '}',
#  '~'}

# %% [markdown]
# ### contraction that is of no use like stopWords
# ### so remove'em

# %%
contractions = {
"ain't": "am not / are not",
"aren't": "are not / am not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he had / he would",
"he'd've": "he would have",
"he'll": "he shall / he will",
"he'll've": "he shall have / he will have",
"he's": "he has / he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how has / how is",
"i'd": "I had / I would",
"i'd've": "I would have",
"i'll": "I shall / I will",
"i'll've": "I shall have / I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it had / it would",
"it'd've": "it would have",
"it'll": "it shall / it will",
"it'll've": "it shall have / it will have",
"it's": "it has / it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she had / she would",
"she'd've": "she would have",
"she'll": "she shall / she will",
"she'll've": "she shall have / she will have",
"she's": "she has / she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as / so is",
"that'd": "that would / that had",
"that'd've": "that would have",
"that's": "that has / that is",
"there'd": "there had / there would",
"there'd've": "there would have",
"there's": "there has / there is",
"they'd": "they had / they would",
"they'd've": "they would have",
"they'll": "they shall / they will",
"they'll've": "they shall have / they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we had / we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what shall / what will",
"what'll've": "what shall have / what will have",
"what're": "what are",
"what's": "what has / what is",
"what've": "what have",
"when's": "when has / when is",
"when've": "when have",
"where'd": "where did",
"where's": "where has / where is",
"where've": "where have",
"who'll": "who shall / who will",
"who'll've": "who shall have / who will have",
"who's": "who has / who is",
"who've": "who have",
"why's": "why has / why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you had / you would",
"you'd've": "you would have",
"you'll": "you shall / you will",
"you'll've": "you shall have / you will have",
"you're": "you are",
"you've": "you have"
}

# %%
contractionSet=set()
for key in contractions:
    contractionSet.add(key)
toBeRemoved = toBeRemoved.union(contractionSet)
print(toBeRemoved,len(toBeRemoved))
# Out:
# {'saw', "he'd", 'hither', 'ever', 'gives', 'indicated', 'seen', "aren't", '$', 'useful', "when've", 'zero', 'ones', 'other', 'f', 'hasn', 'serious', "haven't", 'always', "i'd've", '+', 'none', 'moreover', 'meanwhile', 'tends', 'rd', 'whereafter', 'others', "so's", 'below', 'could', "she's", 'once', 'knows', "let's", 'co', 'available', 'old', 'whereas', 'yes', '!', 'currently', 'entirely', 'fifth', 'maybe', 'down', 'own', 'believe', 'something', "they'll", 'nearly', 'shouldn', 'appear', 'whereby', 'beside', 'uucp', '&', 'thats', 'towards', 'despite', 'whom', 'becomes', 'necessary', 'than', 'quite', 'containing', 'non', 'need', 'consequently', 'go', "'", "it'll", 'out', "y'all'd've", 'thru', 'among', "would've", 'known', 'latterly', 'herein', 'third', 'needn', 'however', 'lately', 'did', 'and', 'inner', 'be', 'specified', 'b', 'unfortunately', 'especially', 'tried', 'consider', 'ok', 'off', 'else', 'normally', "it's", 'aside', 'them', 'indicate', 'hence', 'best', "you're", 'there', "what's", "why've", "needn't", 'latter', 'do', 'alone', 'thoroughly', 'please', '`', 'does', 'an', 'saying', 'elsewhere', 'considering', 'que', "i'm", '?', 'sometimes', 'her', 'both', 'j', 'wherever', "shan't've", 're', 'thereupon', 'think', 'provides', 'thanks', 'nobody', 'seriously', "we'd", 'who', 'edu', '/', 'try', 'except', 'yourselves', 'the', 'was', "mayn't", 'regards', 'into', ')', 'n', 'is', 'together', 'five', "who's", 'which', 'then', 'two', 'oh', 'are', 'h', 'should', 'different', 'whatever', 'described', 'she', 'done', 'wasn', 'over', 'even', 'all', 'beyond', 'thence', "you'll've", 'just', 'never', 'thereby', "should've", 'hopefully', "we're", 'asking', 'onto', '@', 'became', 'again', 'ma', 'obviously', '(', 'wonder', 'used', 'gotten', 'become', "she'll", "it'd've", "you'd've", 'next', 'right', "wouldn't've", 'at', 'might', 'usually', 'already', "can't", 'looks', 'ltd', "must've", 'very', 'hereby', 'less', 'allow', "she'd've", "he's", 'somehow', 'y', 'reasonably', 'your', 'least', 'un', 'specifying', 'plus', 'mostly', 'hi', 'me', "o'clock", "that'd've", 'namely', '|', "wasn't", 'throughout', '*', 'probably', 'thank', 'last', 'several', 'sub', 'our', 'thereafter', "he'll", ',', 'trying', 'weren', 'for', 'along', 'noone', 'first', 'hardly', 'respectively', 'little', "n't", 'almost', 'ignored', '^', 'anyway', "mustn't've", "isn't", "you'd", 'otherwise', "c's", 'on', 'herself', 'came', 'course', 'soon', "what're", "it'll've", "what'll", 'don', 'yourself', 'between', 'every', 'seeming', 'but', 'hello', 'anyhow', 'former', 'afterwards', 'got', 'placed', 'ours', 'too', 'immediate', 'ourselves', 'follows', 'like', "they've", 'much', 'three', 'no', 'forth', 'someone', "she'll've", 'they', 'clearly', 'has', 'greetings', 'insofar', 'inward', 'regardless', 'somewhere', "how'd'y", 'neither', 'further', 'hadn', 'in', 'indeed', 'sent', 'seven', 'sup', '<', 'away', 'haven', "that'd", "who've", ']', 'mustn', 'get', "oughtn't've", 'brief', 'before', "i'll", 'q', "didn't", 'us', 'way', "shouldn't've", "mustn't", 'says', 'furthermore', 'have', 'through', 'instead', '#', 'going', "'re'", 'near', "needn't've", "who'll've", 'behind', 'x', 'keep', "who'll", '"', 'value', 'when', 'th', 'themselves', 'mainly', "ma'am", 'really', 'certainly', 'whereupon', 'able', 'cant', 'selves', 'if', 'somebody', 'mightn', 'accordingly', 'whether', "we'd've", 'beforehand', 'taken', 'cannot', 'regarding', 'becoming', 'gone', 'r', "what've", 'thanx', 'wants', 'what', "here's", 'using', '[', 'its', ':', 'willing', "could've", 'either', 'whither', 'some', "he'll've", 'his', 'where', 'howbeit', 'merely', 'because', 'whoever', "that'll", 'or', "wouldn't", 'gets', 'itself', 'qv', "'cause", 'myself', 'associated', "mightn't've", 'many', 'unto', 'various', 'v', '~', 'formerly', 'those', 'i', 'secondly', '.', 'doesn', "i'd", "a's", 'with', 'my', 'everyone', 'etc', 'see', 'o', 'followed', "where've", 'these', "why's", 'particularly', 'new', 'from', 'up', 'shall', '>', 'so', 'theres', "hadn' ...

# %% [markdown]
# ### number in form of words --toBe removed

# %%
import inflect
p = inflect.engine()
numberth=[p.ordinal(p.number_to_words(i)) for i in range(21)]
tenth=[p.ordinal(p.number_to_words(i)) for i in range(10,101,10)]
tens=[p.number_to_words(i) for i in range(10,101,10)]
numbers=[p.number_to_words(i) for i in range(21)]

number=set()

for i in numberth:
    number.add(i)
for i in numbers:
    number.add(i)
for i in tenth:
    number.add(i)
for i in tens:
    number.add(i)

toBeRemoved =toBeRemoved.union(number)
print(toBeRemoved,len(toBeRemoved))
# Out:
# {'saw', "he'd", 'hither', 'ever', 'gives', 'indicated', 'seen', "aren't", '$', 'useful', "when've", 'zero', 'ones', 'other', 'f', 'thirtieth', 'hasn', 'serious', "haven't", 'always', "i'd've", '+', 'none', 'moreover', 'meanwhile', 'tends', 'rd', 'whereafter', 'sixth', 'others', "so's", 'below', 'could', "she's", 'once', 'knows', "let's", 'co', 'available', 'old', 'whereas', 'yes', '!', 'currently', 'entirely', 'fifth', 'maybe', 'down', 'own', 'believe', 'something', "they'll", 'nearly', 'shouldn', 'appear', 'whereby', 'beside', 'uucp', '&', 'thats', 'towards', 'despite', 'eightieth', 'whom', 'becomes', 'necessary', 'than', 'quite', 'containing', 'non', 'need', 'consequently', 'go', 'fourteen', "'", "it'll", 'out', "y'all'd've", 'thirteenth', 'thru', 'among', "would've", 'fourth', 'known', 'latterly', 'herein', 'third', 'needn', 'however', 'lately', 'eighteen', 'did', 'and', 'inner', 'be', 'specified', 'b', 'fifteen', 'unfortunately', 'especially', 'tried', 'consider', 'ok', 'off', 'else', 'normally', "it's", 'aside', 'them', 'indicate', 'hence', 'best', "you're", 'there', "what's", "why've", "needn't", 'latter', 'do', 'alone', 'thoroughly', 'eighty', 'please', '`', 'does', 'an', 'saying', 'elsewhere', 'considering', 'que', "i'm", '?', 'sometimes', 'her', 'both', 'j', 'wherever', "shan't've", 're', 'thereupon', 'think', 'provides', 'thanks', 'nobody', 'seriously', "we'd", 'who', 'edu', '/', 'try', 'except', 'yourselves', 'the', 'was', "mayn't", 'regards', 'into', ')', 'n', 'is', 'together', 'fifteenth', 'five', "who's", 'which', 'then', 'two', 'oh', 'are', 'h', 'should', 'different', 'whatever', 'described', 'she', 'done', 'wasn', 'thirty', 'over', 'even', 'all', 'beyond', 'thence', "you'll've", 'just', 'never', 'thereby', "should've", 'hopefully', "we're", 'asking', 'onto', '@', 'became', 'one hundred', 'again', 'ma', 'obviously', '(', 'wonder', 'used', 'gotten', 'become', "she'll", "it'd've", "you'd've", 'thirteen', 'next', 'right', "wouldn't've", 'at', 'might', 'usually', 'already', "can't", 'looks', 'ltd', "must've", 'very', 'hereby', 'less', 'allow', "she'd've", "he's", 'somehow', 'y', 'reasonably', 'your', 'least', 'un', 'specifying', 'plus', 'mostly', 'hi', 'me', "o'clock", "that'd've", 'namely', '|', "wasn't", 'throughout', '*', 'probably', 'thank', 'seventeen', 'last', 'several', 'sub', 'our', 'thereafter', "he'll", ',', 'trying', 'weren', 'for', 'along', 'noone', 'first', 'hardly', 'respectively', 'little', "n't", 'almost', 'ignored', 'forty', '^', 'anyway', "mustn't've", "isn't", "you'd", 'otherwise', "c's", 'on', 'herself', 'came', 'course', 'soon', "what're", "it'll've", 'nineteen', "what'll", 'don', 'sixtieth', 'yourself', 'between', 'every', 'seeming', 'but', 'hello', 'anyhow', 'former', 'afterwards', 'got', 'placed', 'ours', 'too', 'immediate', 'twentieth', 'ourselves', 'follows', 'like', "they've", 'much', 'three', 'no', 'forth', 'someone', "she'll've", 'they', 'clearly', 'has', 'greetings', 'insofar', 'inward', 'regardless', 'somewhere', "how'd'y", 'neither', 'further', 'hadn', 'in', 'indeed', 'sent', 'seven', 'sup', '<', 'away', 'haven', "that'd", "who've", ']', 'fortieth', 'mustn', 'get', "oughtn't've", 'brief', 'before', "i'll", 'q', "didn't", 'us', 'way', "shouldn't've", "mustn't", 'says', 'furthermore', 'have', 'through', 'instead', '#', 'going', "'re'", 'near', "needn't've", 'seventy', "who'll've", 'behind', 'x', 'keep', "who'll", '"', 'value', 'when', 'th', 'themselves', 'mainly', "ma'am", 'really', 'certainly', 'whereupon', 'able', 'cant', 'eleventh', 'selves', 'if', 'somebody', 'mightn', 'accordingly', 'whether', "we'd've", 'beforehand', 'taken', 'cannot', 'regarding', 'seventeenth', 'becoming', 'gone', 'eighteenth', 'r', "what've", 'thanx', 'wants', 'what', "here's", 'using', '[', 'its', 'sixteenth', ':', 'willing', "could've", 'either', 'whither', 'twelfth', 'some', "he'll've", 'his', 'where', 'howbeit', 'merely', 'because', 'fifty', 'whoever', "that'll", 'or', "wouldn't", 'gets', 'itself', 'qv', "' ...

# %% [markdown]
# # Remove stopwords

# %%
### Remove stop words
dataWithoutStopWords=list(filter(lambda w: not w in toBeRemoved,data))
print(dataWithoutStopWords,len(dataWithoutStopWords))
###Conclusion
#(5950-3254)=2696 stopWords removed

### 10/8/18
## 5950-3274=2676  removed
# 5902-3226=2676

###16/8/18
##1492-1220=272
# Out:
# ['bonds', 'turmoil', 'glowing', 'send', 'cosmos', 'code', 'carbon', 'world', 'conclude', 'side', 'test', 'sort', 'studies', 'temperatures', 'penzias', 'heavier', 'david', 'makes', 'make', 'gravity', 'party', 'cars', 'todd', 'vehicle', 'collapsed', 'edwin', 'skies', 'left', 'degrees', 'mars', 'destabilizes', 'entire', 'electron', 'helping', 'ca', 'whimper', 'densities', 'measured', 'dwarfs', 'wind', 'kate', 'created', 'combinations', 'fireworks', 'frank', 'made', 'growing', 'results', 'desperation', 'outward', 'thinking', 'scientific', 'nuclear', 'density', 'fusion', 'automobiles', 'precisely', 'listes', 'physics', 'lifeless', 'slight', 'bit', 'pigeons', 'probe', 'suddenly', 'pull', 'identify', 'convinced', 'birthday', 'finite', 'officially', 'cruel', 'quiet', 'acted', 'special', 'positions', 'tony', 'millions', 'creation', 'visible', 'dawn', 'spectrum', 'biblical', 'examining', 'fluctuations', 'wake', 'bloated', 'designed', 'proper', 'champagne', 'percent', 'shoulder', 'coming', 'ripped', 'material', 'naked', 'race', 'beads', 'oak', 'astounding', 'electrons', 'steel', 'leave', 'filled', 'released', 'hundreds', 'massive', 'elements', 'leftover', 'shower', 'enormous', 'trillions', 'crumples', 'gave', 'characteristic', 'speeds', 'incredibly', 'clusters', 'young', 'taking', 'derision', 'extra', 'hurtled', 'cheesy', 'spurt', 'fog', 'emerged', 'galaxy', 'starts', 'map', 'disk', 'days', 'cosmic', 'atoms', 'filaments', 'live', 'mailed', 'bomb', 'explains', 'inter', 'suggests', 'centimeter', 'things', 'dreams', 'touch', 'starting', 'tools', 'foggy', 'arno', 'resolute', 'hilton', 'lift', 'mass', 'works', 'cells', 'nearby', 'grown', 'deeper', 'exist', 'talk', 'unexpected', 'speeding', 'subatomic', 'extremely', 'appears', 'color', 'successively', 'account', 'lydman', 'basic', 'noise', 'tuned', 'mysterious', 'carlos', 'cool', 'objects', 'galaxies', 'neutrons', 'molecules', 'vlt', 'give', 'worst', 'time', 'added', 'genesis', 'wrinkle', 'thousand', 'lamp', 'rang', 'globs', 'fender', 'astrophysicist', 'smashing', 'continued', 'ending', 'ran', 'site', 'individual', 'trees', 'cameras', 'hotter', 'unstable', 'heaviest', 'ridge', 'mother', 'shriveled', 'assembly', 'shrapnel', 'temperature', 'variations', 'gas', 'bind', 'archrival', 'voids', 'perfectly', 'convertible', 'emits', 'experimental', 'calm', 'heavy', 'big', 'making', 'fingerprint', 'place', 'reactors', 'nasa', 'moment', 'andromeda', 'enter', 'chapter', 'generated', 'inescapable', 'crew', 'expensive', 'distances', 'flowed', 'dust', 'tire', 'history', 'conjures', 'exploded', 'collide', 'bright', 'variation', 'droppings', 'breathe', 'spiral', 'links', 'earth', 'amounts', 'plants', 'breath', 'halt', 'end', 'missing', 'rash', 'clues', 'system', 'pens', 'step', 'stiff', 'recent', 'smaller', 'uniform', 'bounces', 'distorted', 'telescope', 'michael', 'atomic', 'mission', 'slowly', 'held', 'tiny', 'located', 'materials', 'blood', 'applause', 'granted', 'tend', 'richer', 'body', 'dense', 'explodes', 'heard', 'astronauts', 'jigsaw', 'war', 'companion', 'nightmare', 'generates', 'year', 'burn', 'constructed', 'grabbed', 'conclusion', 'building', 'job', 'amount', 'lives', 'detail', 'east', 'day', 'equally', 'eventually', 'greatest', 'creative', 'expanded', 'solar', 'unravel', 'lifted', 'led', 'phase', 'shock', 'eons', 'restarts', 'amazing', 'specific', 'times', 'create', 'built', 'rapid', 'part', 'called', 'island', 'fahrenheit', 'removing', 'reveals', 'tapestry', 'accelerates', 'cloud', 'flying', 'accumulate', 'evaporate', 'punches', 'radiator', 'atom', 'inflates', 'infinitely', 'extreme', 'humans', 'discover', 'signatures', 'life', 'disappear', 'years', 'equation', 'spawn', 'consciousness', 'mc', 'machine', 'interesting', 'math', 'bones', 'processes', 'liquid', 'perlmutter', 'bond', 'nebula', 'nucleus', 'rates', 'chromium', 'turned', 'immunity', 'faint', 'dark', 'annihilation', 'region', 'nature', 'additional', 'animal', 'smith', 'street', 'empty', 'tower', 'deaths', 'weapons', 'picture', 'red', 'r ...

# %% [markdown]
# ## read commonWords from file

# %%
with open('/home/sarkijatru/Desktop/srikarProject/commonWords.txt', 'r') as myfile1:
    data1=myfile1.read().replace('\n', ' ')# read file a replace newLine with space so that split can be performed

# %% [markdown]
# # generate all possible forms of word from commonWords
# ## and
# # Remove common words

# %%
commonWordsArray=data1.split()
commonWordsArray=[x.upper() for x in commonWordsArray] #capitalize'em

dataWithoutStopWords=[x.upper() for x in dataWithoutStopWords] #capitalize'em

import nltk
from nltk.corpus import wordnet as wn
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

lemmatizer = WordNetLemmatizer()

import inflect
p = inflect.engine()

forms = set() #We'll store the derivational forms in a set to eliminate duplicates
for commonWord in commonWordsArray:
    for word in wn.lemmas(commonWord): #for each commonWord lemma in WordNet
        forms.add(word.name()) #add the lemma itself
        for relatedWord in word.derivationally_related_forms(): #for each related lemma
            forms.add(relatedWord.name()) #add the related lemma\

    for word in wn.lemmas(lemmatizer.lemmatize(commonWord)):
        forms.add(word.name()) #add the lemma itself
        for relatedWord in word.derivationally_related_forms(): #for each related lemma
            forms.add(relatedWord.name()) #add the related lemma\

    for word in wn.lemmas(ps.stem(commonWord)):
        forms.add(word.name()) #add the lemma itself
        for relatedWord in word.derivationally_related_forms(): #for each related lemma
            forms.add(relatedWord.name()) #add the related lemma\

    forms.add(lemmatizer.lemmatize(commonWord))
    forms.add(commonWord)
    forms.add(ps.stem(commonWord))
    forms.add(p.plural(commonWord))
    
forms=[x.upper() for x in forms]# capitalize'em

dataWithoutCommonWordsAndItsForms=list(filter(lambda w: not w in forms,dataWithoutStopWords))
print(dataWithoutCommonWordsAndItsForms,len(dataWithoutCommonWordsAndItsForms))
# Out:
# ['TURMOIL', 'GLOWING', 'COSMOS', 'PENZIAS', 'HEAVIER', 'COLLAPSED', 'EDWIN', 'SKIES', 'DESTABILIZES', 'WHIMPER', 'DENSITIES', 'DWARFS', 'FIREWORKS', 'DESPERATION', 'OUTWARD', 'LISTES', 'LIFELESS', 'PIGEONS', 'CRUEL', 'ACTED', 'FLUCTUATIONS', 'BLOATED', 'RIPPED', 'ASTOUNDING', 'LEFTOVER', 'TRILLIONS', 'CRUMPLES', 'INCREDIBLY', 'DERISION', 'HURTLED', 'CHEESY', 'SPURT', 'EMERGED', 'COSMIC', 'FILAMENTS', 'CENTIMETER', 'ARNO', 'RESOLUTE', 'SUBATOMIC', 'SUCCESSIVELY', 'LYDMAN', 'TUNED', 'GALAXIES', 'NEUTRONS', 'VLT', 'WRINKLE', 'GLOBS', 'FENDER', 'ASTROPHYSICIST', 'SMASHING', 'HOTTER', 'UNSTABLE', 'HEAVIEST', 'SHRIVELED', 'SHRAPNEL', 'ARCHRIVAL', 'EMITS', 'FINGERPRINT', 'REACTORS', 'ANDROMEDA', 'INESCAPABLE', 'FLOWED', 'CONJURES', 'EXPLODED', 'COLLIDE', 'DROPPINGS', 'SPIRAL', 'HALT', 'RASH', 'CLUES', 'STIFF', 'BOUNCES', 'DISTORTED', 'APPLAUSE', 'RICHER', 'EXPLODES', 'ASTRONAUTS', 'JIGSAW', 'GRABBED', 'UNRAVEL', 'LIFTED', 'EONS', 'RESTARTS', 'FAHRENHEIT', 'TAPESTRY', 'ACCELERATES', 'ACCUMULATE', 'EVAPORATE', 'RADIATOR', 'INFLATES', 'INFINITELY', 'DISAPPEAR', 'SPAWN', 'PERLMUTTER', 'NEBULA', 'NUCLEUS', 'CHROMIUM', 'FAINT', 'ANNIHILATION', 'PIGEON', 'TIGHTLY', 'PILLARS', 'WEIGH', 'ASTROPHYSICS', 'EXPLODING', 'UNDERWENT', 'COOLED', 'EMITTED', 'ENCUMBERED', 'WAITED', 'SPERGEL', 'FAINTER', 'FACTORIES', "'RE", 'EVOLVED', 'ZACAPA', 'FORGED', 'SWIRLING', 'KNOB', 'VIBRATED', 'BUMPS', 'LATED', 'NUCLEI', 'ACCELERATOR', 'MITTENS', 'IMPROVISED', 'BLINDING', 'ROTATING', 'AFTERMATH', 'RECREATES', 'STARDUST', 'TORN', 'IMBALANCE', 'BLING', 'CONDENSE', 'RESTART', 'SPACESUIT', 'PINPOINT', 'MUTUALLY', 'SMASHED', 'ASTRONAUT', 'OBLITERATED', 'NEBULAE', 'MELTING', 'CELEBRATED', 'VISCOSITY', 'FUSED', 'IMPERFECTIONS', 'ESCAPING', 'SHOCKWAVE', 'SQUARED', 'CRIPPLED', 'GOOSE', 'GRIND', 'DEBRIS', 'ROOSTING', 'OAKRIDGE', 'FRICTION', 'BRIGHTER', 'ACCELERATE', 'UNCOUNTABLE', 'HURDLES', 'BROOKHAVEN', 'CROWDED', 'SEQUENTIALLY', 'SUCCEEDED', 'MYSTERIES', 'DIMMED', 'UNPRECEDENTED', 'MEMENTO', 'SMASH', 'DULL', 'HOFFMAN', 'SUPERNOVAS', 'SLOWED', 'ANALYZING', 'COINED', 'CLUMPED', 'TROUBLESOME', 'DWARF', 'NEUTRON', 'MILLIONTHS', 'CLUMPS', 'PINHEAD', 'MILLIONTH', 'GLIMPSE', 'ANTIMATTER', 'SUPERHEATED', 'ASYMMETRY', 'TRILLION', 'INYX', 'STRETCHED', 'ANNIHILATED', "'VE", 'NURSERIES', 'SUNK', 'TRILLIONTH', 'HUBBLE', 'FIREBALL', 'WARPED', 'DISASSOCIATE', 'AMAZED', 'FLASHLIGHT', 'CANOPY', 'KRAUSS', 'WILDEST', 'ASTONISHING', 'EINSTEIN', 'SAUL', 'PROTONS', 'ASTRONOMER', 'DISMAL', 'THERMO', 'CONTRADICTS', 'STUMBLE', 'COLLIDER', 'UNEVEN', "'LL", 'RETIRES', 'SMASHES', 'FAIRLANE', 'ASTRONOMERS', 'LEFTOVERS', 'COLDER', 'STARLIGHT', 'ORIGINATED', 'DENSER', 'HUBBELL', 'IGNITED', 'EVOLVING', 'RELATIVISTIC', 'INSTABILITY', 'HOYLE', 'HEMISPHERE', 'DECAY', 'STRICKEN', 'RIPPLING', 'FUSING', 'OPAQUE', 'FLEDGLING', 'TIPPING', 'BEACONS', 'COSMOLOGISTS', 'NEWBORN', 'BURNED', 'DISCOVERING', 'ELIMINATED', 'RELEASING', 'CRUNCHES', 'TICKING', 'DISCOVERIES', 'CRUNCH', 'SATA', 'GLOOMY', 'FORTUNATELY', 'BILLIONTH', 'CALMER', 'TRAPPED', 'RECREATING', 'COLLISIONS', 'ASTROPHYSICISTS', 'INTERCHANGEABLE', 'TEEMING', 'MAGNESIUM', 'SPECK', 'HELIUM', 'BRIGHTLY', 'STELLAR', 'SURPASS', "'M", 'GASES', 'SUPERNOVA', 'DUSK', 'GRAVITATIONAL'] 274

# %%
len(dataWithoutCommonWordsAndItsForms)
###conclusion :9/8/18 :thursday 
# 3254-1650=1604 common words removed

###10/8/18 friday
# 3254-1409=1845 common words removed

# 3 things added
# 3274-1443=1831 removed

###11/8/18
# inflect plurals
# 3274-1333=1941 removed

###
##1220-291=929
# Out:
# 274

# %%
finalWordSet=set()
for i in range(len(dataWithoutCommonWordsAndItsForms)):
    finalWordSet.add(dataWithoutCommonWordsAndItsForms[i])

# %%
j=0
for i in finalWordSet:
    if len(i)>2:
        j+=1
print(j)
# Out:
# 273

# %%
j=0
finalNewWords=[]
for i in finalWordSet:
    if len(i)>3:
        finalNewWords.append(i)

# %%
temp="/home/sarkijatru/Desktop/srikarProject/python/newWords.txt"
newWords=open(temp,"w")

#str = ''.join(str(i) for i in finalWordSet)
for i in finalNewWords:
    newWords.write(i)
    newWords.write('\n')
newWords.close()

# %% [markdown]
# # new project

# %% [markdown]
# ## colour all new words in subtitle

# %% [markdown]
# ### idea 1:
#     read those new words
#     find'em from subtitle
#     add code for applying color

# %%
with open(temp,"r") as w:
    words=w.readlines()

wordSet=[i.replace('\n','') for i in words]
w.close()

# with open (inputFile, "r") as myfile:
#     subtitle=myfile.read().upper()

with open (inputFile, "r") as myfile:
    subtitle=myfile.readlines()
myfile.close()

newColor="#FFFF00"#blue
oldColor="#CCCCCC"#old

for i in range(len(subtitle)):
    for eachWord in re.findall(r'\b\w+\b',subtitle[i]):
        if not eachWord.isdecimal():# only for words-> excluding intergers
            if eachWord.upper() in wordSet:
                print(eachWord)
                if "font" in subtitle[i]:# finding particular word 
                    newReplacement="</font><font color=\""+newColor+"\">"+eachWord.upper()+"</font><font>"
                else: 
                    newReplacement="<font color=\""+newColor+"\">"+eachWord.upper()+"</font>"
                subtitle[i]=subtitle[i].replace(eachWord,newReplacement)
                print(subtitle[i])
#to see the list of new words
#print(wordSet)
# Out:
# galaxies
# our<font color="#E5E5E5"> universe the </font><font color="#FFFF00">GALAXIES</font><font> the solar</font>
#
# cosmos
# <font color="#E5E5E5">planet and what you see is a vast </font><font color="#FFFF00">COSMOS</font><font></font>
#
# teeming
# <font color="#FFFF00">TEEMING</font> with billions of stars and
#
# galaxies
# <font color="#CCCCCC"></font><font color="#FFFF00">GALAXIES</font><font> turn back</font><font color="#E5E5E5"> the clock over 13</font>
#
# galaxies
# </font><font color="#FFFF00">GALAXIES</font><font><font color="#CCCCCC"> and the building blocks of life</font>
#
# fairlane
# it's a 1956 ford <font color="#FFFF00">FAIRLANE</font> convertible
#
# chromium
# silicon <font color="#FFFF00">CHROMIUM</font> and carbon each and
#
# Krauss
# physicist Lawrence <font color="#FFFF00">KRAUSS</font> studies how
#
# Stardust
# to be<font color="#CCCCCC"> here we really are parts </font><font color="#FFFF00">STARDUST</font><font></font>
#
# dusk
# and part Big Bang <font color="#FFFF00">DUSK</font> most of the atoms
#
# cosmic
# we really<font color="#E5E5E5"> are truly </font><font color="#FFFF00">COSMIC</font><font> individuals</font>
#
# evolved
# <font color="#FFFF00">EVOLVED</font> so when we look at this car of
#
# stellar
# from <font color="#FFFF00">STELLAR</font> explosions from supernova
#
# supernova
# from <font color="#FFFF00">STELLAR</font> explosions from </font><font color="#FFFF00">SUPERNOVA</font><font>
#
# stellar
# processes and from <font color="#FFFF00">STELLAR</font> evolution but
#
# speck
# tiny<font color="#E5E5E5"> </font><font color="#FFFF00">SPECK</font><font> of light appears it was</font>
#
# infinitely
# <font color="#FFFF00">INFINITELY</font> hot inside this tiny fireball
#
# fireball
# <font color="#FFFF00">INFINITELY</font> hot inside this tiny </font><font color="#FFFF00">FIREBALL</font><font>
#
# cosmic
# beginning<font color="#E5E5E5"> of time the</font><font color="#CCCCCC"> </font><font color="#FFFF00">COSMIC</font><font> clock was</font>
#
# ticking
# <font color="#FFFF00">TICKING</font> time could flow and space expand
#
# galaxies
# energy in all of the <font color="#FFFF00">GALAXIES</font> was once
#
# originated
# <font color="#FFFF00">ORIGINATED</font> from the brilliant work of
#
# astronomer
# American <font color="#FFFF00">ASTRONOMER</font> Edwin Hubble back in
#
# Edwin
# American <font color="#FFFF00">ASTRONOMER</font> </font><font color="#FFFF00">EDWIN</font><font> Hubble back in
#
# Hubble
# American <font color="#FFFF00">ASTRONOMER</font> </font><font color="#FFFF00">EDWIN</font><font> </font><font color="#FFFF00">HUBBLE</font><font> back in
#
# astronomers
# the 1920s most <font color="#FFFF00">ASTRONOMERS</font> believe that
#
# Hubble
# <font color="#CCCCCC">the Milky Way but </font><font color="#FFFF00">HUBBLE</font><font> wasn't</font>
#
# swirling
# convinced he studied a <font color="#FFFF00">SWIRLING</font> cloud of
#
# Andromeda
# light called the<font color="#E5E5E5"> </font><font color="#FFFF00">ANDROMEDA</font><font> nebula and</font>
#
# nebula
# light called the<font color="#E5E5E5"> </font><font color="#FFFF00">ANDROMEDA</font><font> </font><font color="#FFFF00">NEBULA</font><font> and</font>
#
# galaxies
# he showed<font color="#CCCCCC"> that these other </font><font color="#FFFF00">GALAXIES</font><font> were</font>
#
# Spergel
# theoretical physicist<font color="#CCCCCC"> David </font><font color="#FFFF00">SPERGEL</font><font> is a</font>
#
# evolved
# universe <font color="#FFFF00">EVOLVED</font> no one knows exactly
#
# billionth
# when the universe was a </font><font color="#FFFF00">BILLIONTH</font><font> of<font color="#CCCCCC"> a</font>
#
# billionth
# </font><font color="#FFFF00">BILLIONTH</font><font><font color="#E5E5E5"> of a </font><font color="#FFFF00">BILLIONTH</font><font> of</font><font color="#CCCCCC"> a </font><font color="#FFFF00">BILLIONTH</font><font></font>
#
# billionth
# </font><font color="#FFFF00">BILLIONTH</font><font><font color="#E5E5E5"> of a </font><font color="#FFFF00">BILLIONTH</font><font> of</font><font color="#CCCCCC"> a </font><font color="#FFFF00">BILLIONTH</font><font></font>
#
# billionth
# </font><font color="#FFFF00">BILLIONTH</font><font><font color="#E5E5E5"> of a </font><font color="#FFFF00">BILLIONTH</font><font> of</font><font color="#CCCCCC"> a </font><font color="#FFFF00">BILLIONTH</font><font></font>
#
# trillion
# than<font color="#CCCCCC"> a </font><font color="#FFFF00">TRILLION</font><font> </font><font color="#FFFF00">TRILLION</font><font>th of a second</font>
#
# trillionth
# than<font color="#CCCCCC"> a </font><font color="#FFFF00">TRILLION</font><font> </font><font color="#FFFF00">TRILLION</font><font>th of a second</font>
#
# unstable
# universe was very <font color="#FFFF00">UNSTABLE</font> and underwent
#
# underwent
# universe was very <font color="#FFFF00">UNSTABLE</font> and </font><font color="#FFFF00">UNDERWENT</font><font>
#
# spurt
# an enormous growth <font color="#FFFF00">SPURT</font> during this
#
# incredibly
# period of </font><font color="#FFFF00">INCREDIBLY</font><font><font color="#E5E5E5"> rapid expansion</font>
#
# inflates
# <font color="#E5E5E5">this hot glass ball </font><font color="#FFFF00">INFLATES</font><font> so did the</font>
#
# cooled
# <font color="#FFFF00">COOLED</font>
#
# trillion
# a <font color="#FFFF00">TRILLION</font> <font color="#FFFF00">TRILLION</font>th of a second after
#
# trillionth
# a <font color="#FFFF00">TRILLION</font> <font color="#FFFF00">TRILLION</font>th of a second after
#
# trillionth
# a <font color="#FFFF00">TRILLIONTH</font> of a second after the Big
#
# newborn
# Bang and our <font color="#FFFF00">NEWBORN</font> universe was still
#
# Einstein
# <font color="#FFFF00">EINSTEIN</font>'s famous equation e equals MC
#
# squared
# <font color="#FFFF00">SQUARED</font> showed that mass and energy are
#
# interchangeable
# </font><font color="#FFFF00">INTERCHANGEABLE</font><font><font color="#E5E5E5"> it gave us the knowledge</font>
#
# explodes
# </font><font color="#FFFF00">EXPLODES</font><font> a tiny amount<font color="#E5E5E5"> of matter is</font>
#
# annihilated
# <font color="#FFFF00">ANNIHILATED</font> and converted into energy in
#
# archrival
# and<font color="#CCCCCC"> its </font><font color="#FFFF00">ARCHRIVAL</font><font> antimatter and when</font>
#
# antimatter
# and<font color="#CCCCCC"> its </font><font color="#FFFF00">ARCHRIVAL</font><font> </font><font color="#FFFF00">ANTIMATTER</font><font> and when</font>
#
# obliterated
# these two met they <font color="#FFFF00">OBLITERATED</font> each
#
# antimatter
# <font color="#FFFF00">ANTIMATTER</font>
#
# mutually
# if they <font color="#FFFF00">MUTUALLY</font> annihilated each other
#
# annihilated
# if they <font color="#FFFF00">MUTUALLY</font> </font><font color="#FFFF00">ANNIHILATED</font><font> each other
#
# galaxies
# no <font color="#FFFF00">GALAXIES</font> stars planets or life
#
# fortunately
# <font color="#FFFF00">FORTUNATELY</font> for us there was an
#
# imbalance
# <font color="#FFFF00">IMBALANCE</font> for every 100 million anti
#
# leftover
# matter<font color="#CCCCCC"> </font><font color="#FFFF00">LEFTOVER</font><font> in each volume and that</font>
#
# imbalance
# <font color="#FFFF00">IMBALANCE</font> led to all matter we see in
#
# galaxies
# the<font color="#E5E5E5"> universe </font><font color="#FFFF00">GALAXIES</font><font> stars planets even</font>
#
# astrophysicist
# </font><font color="#FFFF00">ASTROPHYSICIST</font><font><font color="#E5E5E5"> Carlos Frank from Durham</font>
#
# debris
# little bit of <font color="#FFFF00">DEBRIS</font> left over from the
#
# annihilation
# <font color="#FFFF00">ANNIHILATION</font> of matter and antimatter
#
# antimatter
# <font color="#FFFF00">ANNIHILATION</font> of matter and </font><font color="#FFFF00">ANTIMATTER</font><font>
#
# leftovers
# <font color="#E5E5E5">were the </font><font color="#FFFF00">LEFTOVERS</font><font> of that process if</font>
#
# asymmetry
# slight <font color="#FFFF00">ASYMMETRY</font> between matter and
#
# antimatter
# </font><font color="#FFFF00">ANTIMATTER</font><font> the universe would have<font color="#E5E5E5"> been</font>
#
# galaxies
# structure there would be no <font color="#FFFF00">GALAXIES</font>
#
# newborn
# this <font color="#FFFF00">NEWBORN</font> universe was like has
#
# cosmologists
# challenged <font color="#FFFF00">COSMOLOGISTS</font> since the Big
#
# Applause
# [<font color="#FFFF00">APPLAUSE</font>]
#
# relativistic
# it's<font color="#E5E5E5"> called the </font><font color="#FFFF00">RELATIVISTIC</font><font> heavy ion</font>
#
# collider
# <font color="#FFFF00">COLLIDER</font> Rick for short and it's located
#
# Brookhaven
# <font color="#E5E5E5">at the </font><font color="#FFFF00">BROOKHAVEN</font><font> National Laboratory on</font>
#
# millionths
# to<font color="#E5E5E5"> ten </font><font color="#FFFF00">MILLIONTHS</font><font> of a second after the</font>
#
# SATA
# here scientists like<font color="#E5E5E5"> Todd</font><font color="#CCCCCC"> </font><font color="#FFFF00">SATA</font><font> gotta</font>
#
# accelerates
# <font color="#FFFF00">ACCELERATES</font> subatomic particles close to
#
# subatomic
# <font color="#FFFF00">ACCELERATES</font> </font><font color="#FFFF00">SUBATOMIC</font><font> particles close to
#
# smash
# the speed of<font color="#CCCCCC"> light</font><font color="#E5E5E5"> and then </font><font color="#FFFF00">SMASH</font><font> them</font>
#
# collide
# second and then<font color="#CCCCCC"> </font><font color="#FFFF00">COLLIDE</font><font> inside this</font>
#
# smash
# when they <font color="#FFFF00">SMASH</font> into each other they
#
# hotter
# billions of times </font><font color="#FFFF00">HOTTER</font><font> than<font color="#CCCCCC"> the center</font>
#
# smashing
# <font color="#FFFF00">SMASHING</font> these nuclei together is
#
# nuclei
# <font color="#FFFF00">SMASHING</font> these </font><font color="#FFFF00">NUCLEI</font><font> together is
#
# melting
# <font color="#FFFF00">MELTING</font> matter creating matter hot
#
# glimpse
# enough to<font color="#E5E5E5"> give us</font><font color="#CCCCCC"> a </font><font color="#FFFF00">GLIMPSE</font><font></font><font color="#E5E5E5"> of what the</font>
#
# collide
# particles <font color="#FFFF00">COLLIDE</font> they break open and
#
# discovering
# particles it's a bit<font color="#E5E5E5"> like </font><font color="#FFFF00">DISCOVERING</font><font></font>
#
# smash
# </font><font color="#FFFF00">SMASH</font><font> into each other you can raise<font color="#CCCCCC"> two</font>
#
# retires
# </font><font color="#FFFF00">RETIRES</font><font> together and smash them<font color="#CCCCCC"> into</font>
#
# smash
# </font><font color="#FFFF00">RETIRES</font><font> together and </font><font color="#FFFF00">SMASH</font><font> them<font color="#CCCCCC"> into</font>
#
# radiator
# comes out here a <font color="#FFFF00">RADIATOR</font> comes out
#
# Brookhaven
# at <font color="#FFFF00">BROOKHAVEN</font> have discovered is that
#
# superheated
# within these <font color="#FFFF00">SUPERHEATED</font> collisions a
#
# collisions
# within these <font color="#FFFF00">SUPERHEATED</font> </font><font color="#FFFF00">COLLISIONS</font><font> a
#
# contradicts
# and this<font color="#E5E5E5"> matter </font><font color="#FFFF00">CONTRADICTS</font><font> the previous</font>
#
# hotter
# times </font><font color="#FFFF00">HOTTER</font><font> than<font color="#CCCCCC"> the surface of the Sun</font>
#
# vibrated
# </font><font color="#FFFF00">VIBRATED</font><font> so fast that it<font color="#E5E5E5"> had no</font>
#
# friction
# stickiness there was no <font color="#FFFF00">FRICTION</font> and it
#
# flowed
# <font color="#FFFF00">FLOWED</font> perfectly this liquid is perfect
#
# viscosity
# it<font color="#CCCCCC"> has no </font><font color="#FFFF00">VISCOSITY</font><font> in some</font><font color="#E5E5E5"> sense it</font>
#
# trillion
# it's a <font color="#FFFF00">TRILLION</font> degrees hot inside the
#
# collider
# </font><font color="#FFFF00">COLLIDER</font><font> this<font color="#E5E5E5"> amazing liquid universe</font>
#
# Brookhaven
# second<font color="#E5E5E5"> the </font><font color="#FFFF00">BROOKHAVEN</font><font> scientists have</font>
#
# succeeded
# <font color="#FFFF00">SUCCEEDED</font> in recreating conditions that
#
# recreating
# <font color="#FFFF00">SUCCEEDED</font> in </font><font color="#FFFF00">RECREATING</font><font> conditions that
#
# turmoil
# liquid<font color="#E5E5E5"> it was in </font><font color="#FFFF00">TURMOIL</font><font> it was full</font><font color="#CCCCCC"> of</font>
#
# subatomic
# </font><font color="#FFFF00">SUBATOMIC</font><font> particles<font color="#E5E5E5"> smashing into each</font>
#
# smashing
# </font><font color="#FFFF00">SUBATOMIC</font><font> particles<font color="#E5E5E5"> </font><font color="#FFFF00">SMASHING</font><font> into each</font>
#
# releasing
# other <font color="#FFFF00">RELEASING</font> more and more energy
#
# slowed
# particles<font color="#E5E5E5"> </font><font color="#FFFF00">SLOWED</font><font> down they would never</font>
#
# galaxies
# never create the <font color="#FFFF00">GALAXIES</font> and stars or
#
# millionth
# the universe is now<font color="#E5E5E5"> one </font><font color="#FFFF00">MILLIONTH</font><font> of a</font>
#
# turmoil
# incredible </font><font color="#FFFF00">TURMOIL</font><font> of<font color="#CCCCCC"> the first</font>
#
# millionth
# </font><font color="#FFFF00">MILLIONTH</font><font> of a second<font color="#E5E5E5"> the universe was</font>
#
# cosmos
# expanding <font color="#FFFF00">COSMOS</font> cooled sufficiently for
#
# cooled
# expanding <font color="#FFFF00">COSMOS</font> </font><font color="#FFFF00">COOLED</font><font> sufficiently for
#
# protons
# <font color="#FFFF00">PROTONS</font> and neutrons to bind together
#
# neutrons
# <font color="#FFFF00">PROTONS</font> and </font><font color="#FFFF00">NEUTRONS</font><font> to bind together
#
# nuclei
# and form the first atomic <font color="#FFFF00">NUCLEI</font>
#
# helium
# hydrogen and <font color="#FFFF00">HELIUM</font> these were not yet
#
# cooled
# <font color="#E5E5E5">the Milky Way it had </font><font color="#FFFF00">COOLED</font><font> from</font>
#
# Fahrenheit
# billions<font color="#CCCCCC"> of degrees </font><font color="#FFFF00">FAHRENHEIT</font><font> to a few</font>
#
# cooled
# thousand as it <font color="#FFFF00">COOLED</font> the electrons
#
# slowed
# <font color="#FFFF00">SLOWED</font> down the universe was now ready
#
# Arno
# universe was <font color="#FFFF00">ARNO</font> Penzias
#
# Penzias
# universe was <font color="#FFFF00">ARNO</font> </font><font color="#FFFF00">PENZIAS</font><font>
#
# Penzias
# 1963<font color="#E5E5E5"> thirty-year-old </font><font color="#FFFF00">PENZIAS</font><font> and his</font>
#
# cosmic
# <font color="#FFFF00">COSMIC</font> radio waves but they would
#
# stumble
# <font color="#FFFF00">STUMBLE</font> on one of the greatest
#
# discoveries
# <font color="#FFFF00">DISCOVERIES</font> of all time as they started
#
# eliminated
# coming<font color="#E5E5E5"> from the sky we </font><font color="#FFFF00">ELIMINATED</font><font> very</font>
#
# eliminated
# were </font><font color="#FFFF00">ELIMINATED</font><font> in desperation<font color="#CCCCCC"> the</font><font color="#E5E5E5"> two</font>
#
# desperation
# were </font><font color="#FFFF00">ELIMINATED</font><font> in </font><font color="#FFFF00">DESPERATION</font><font><font color="#CCCCCC"> the</font><font color="#E5E5E5"> two</font>
#
# pigeons
# <font color="#FFFF00">PIGEONS</font> roosting in the antenna and it
#
# roosting
# <font color="#FFFF00">PIGEONS</font> </font><font color="#FFFF00">ROOSTING</font><font> in the antenna and it
#
# droppings
# was covered<font color="#CCCCCC"> with </font><font color="#FFFF00">DROPPINGS</font><font> they wanted</font>
#
# pigeons
# if the <font color="#FFFF00">PIGEONS</font> were the source of the
#
# droppings
# solution the <font color="#FFFF00">DROPPINGS</font> and the pigeons
#
# pigeons
# solution the <font color="#FFFF00">DROPPINGS</font> and the </font><font color="#FFFF00">PIGEONS</font><font>
#
# pigeon
# to removing the <font color="#FFFF00">PIGEON</font> droppings we also
#
# droppings
# to removing the <font color="#FFFF00">PIGEON</font> </font><font color="#FFFF00">DROPPINGS</font><font> we also
#
# pigeons
# have<font color="#E5E5E5"> to remove</font><font color="#CCCCCC"> the </font><font color="#FFFF00">PIGEONS</font><font> that was a</font>
#
# troublesome
# the<font color="#E5E5E5"> </font><font color="#FFFF00">TROUBLESOME</font><font> pigeons gone the</font>
#
# pigeons
# the<font color="#E5E5E5"> </font><font color="#FFFF00">TROUBLESOME</font><font> </font><font color="#FFFF00">PIGEONS</font><font> gone the</font>
#
# disappear
# mysterious signal would not <font color="#FFFF00">DISAPPEAR</font>
#
# inyx
# and so we left with the <font color="#FFFF00">INYX</font> Kate almost
#
# inescapable
# <font color="#FFFF00">INESCAPABLE</font> conclusion that this
#
# Penzias
# signal detected by <font color="#FFFF00">PENZIAS</font> and Wilson
#
# discoveries
# important scientific<font color="#E5E5E5"> </font><font color="#FFFF00">DISCOVERIES</font><font> of all</font>
#
# trapped
# <font color="#FFFF00">TRAPPED</font> the universe was foggy
#
# flashlight
# imagine a <font color="#FFFF00">FLASHLIGHT</font> beam in a fog of
#
# bounces
# <font color="#E5E5E5">smoke the light </font><font color="#FFFF00">BOUNCES</font><font> back and forth</font>
#
# trapped
# </font><font color="#FFFF00">TRAPPED</font><font> in the<font color="#E5E5E5"> hot baby universe a dense</font>
#
# escaping
# </font><font color="#FFFF00">ESCAPING</font><font> but<font color="#E5E5E5"> as the universe continued</font>
#
# cruel
# to expand and </font><font color="#FFFF00">CRUEL</font><font> the<font color="#E5E5E5"> electrons slowed</font>
#
# slowed
# to expand and </font><font color="#FFFF00">CRUEL</font><font> the<font color="#E5E5E5"> electrons </font><font color="#FFFF00">SLOWED</font><font></font>
#
# protons
# down <font color="#FFFF00">PROTONS</font> then grabbed these calmer
#
# grabbed
# down <font color="#FFFF00">PROTONS</font> then </font><font color="#FFFF00">GRABBED</font><font> these calmer
#
# calmer
# down <font color="#FFFF00">PROTONS</font> then </font><font color="#FFFF00">GRABBED</font><font> these </font><font color="#FFFF00">CALMER</font><font>
#
# helium
# first hydrogen and then <font color="#FFFF00">HELIUM</font> the
#
# crowded
# universe was suddenly much less <font color="#FFFF00">CROWDED</font>
#
# lifted
# with electrons the fog <font color="#FFFF00">LIFTED</font> and light
#
# trapped
# was no longer <font color="#FFFF00">TRAPPED</font> it hurtled out
#
# hurtled
# was no longer <font color="#FFFF00">TRAPPED</font> it </font><font color="#FFFF00">HURTLED</font><font> out
#
# blinding
# across<font color="#CCCCCC"> the universe creating a </font><font color="#FFFF00">BLINDING</font><font></font>
#
# opaque
# would have strongly seen this <font color="#FFFF00">OPAQUE</font>
#
# dimmed
# over time this burst of light <font color="#FFFF00">DIMMED</font> and
#
# cooled
# <font color="#FFFF00">COOLED</font> and became microwave radiation it
#
# faint
# was this <font color="#FFFF00">FAINT</font> 13 billion year old
#
# Penzias
# microwave signal but <font color="#FFFF00">PENZIAS</font> and Wilson
#
# tuned
# you<font color="#E5E5E5"> </font><font color="#FFFF00">TUNED</font><font> between channels turn the knob</font>
#
# knob
# you<font color="#E5E5E5"> </font><font color="#FFFF00">TUNED</font><font> between channels turn the </font><font color="#FFFF00">KNOB</font><font></font>
#
# tuned
# </font><font color="#FFFF00">TUNED</font><font> to a station a tiny<font color="#E5E5E5"> fraction of</font>
#
# memento
# </font><font color="#FFFF00">MEMENTO</font><font> and<font color="#CCCCCC"> it's</font><font color="#E5E5E5"> kind of amazing to</font>
#
# helium
# hydrogen and </font><font color="#FFFF00">HELIUM</font><font> atoms but<font color="#E5E5E5"> the world</font>
#
# helium
# </font><font color="#FFFF00">HELIUM</font><font> atoms to fuse and to do<font color="#CCCCCC"> that it</font>
#
# colder
# had dropped so far that it was <font color="#FFFF00">COLDER</font>
#
# Fahrenheit
# </font><font color="#FFFF00">FAHRENHEIT</font><font> it was<font color="#CCCCCC"> also</font><font color="#E5E5E5"> dark it would</font>
#
# gloomy
# have remained<font color="#E5E5E5"> a very </font><font color="#FFFF00">GLOOMY</font><font> place full</font>
#
# galaxies
# of gas but without <font color="#FFFF00">GALAXIES</font> stars or
#
# evolved
# <font color="#FFFF00">EVOLVED</font> it shows that when the universe
#
# emerged
# <font color="#FFFF00">EMERGED</font> from the Big Bang it was uneven
#
# uneven
# <font color="#FFFF00">EMERGED</font> from the Big Bang it was </font><font color="#FFFF00">UNEVEN</font><font>
#
# rash
# was his <font color="#FFFF00">RASH</font> in the face of the baby
#
# dull
# would have<font color="#E5E5E5"> been a very </font><font color="#FFFF00">DULL</font><font> place the</font>
#
# clues
# first <font color="#FFFF00">CLUES</font> as to how these cracks
#
# galaxies
# developed into <font color="#FFFF00">GALAXIES</font> and stars came
#
# Penzias
# by <font color="#FFFF00">PENZIAS</font> and Wilson so it pens east
#
# cosmologists
# <font color="#FFFF00">COSMOLOGISTS</font> then did for the next 25
#
# starlight
# our eyes detect only<font color="#E5E5E5"> visible </font><font color="#FFFF00">STARLIGHT</font><font></font>
#
# faint
# the Sun it picked up the <font color="#FFFF00">FAINT</font> radiation
#
# rippling
# that<font color="#E5E5E5"> has been </font><font color="#FFFF00">RIPPLING</font><font> around the</font>
#
# cosmic
# we look at the </font><font color="#FFFF00">COSMIC</font><font><font color="#CCCCCC"> background</font>
#
# dull
# universe looked very <font color="#FFFF00">DULL</font> and seemed to
#
# fluctuations
# <font color="#FFFF00">FLUCTUATIONS</font> these tiny <font color="#FFFF00">FLUCTUATIONS</font>
#
# fluctuations
# <font color="#FFFF00">FLUCTUATIONS</font> these tiny <font color="#FFFF00">FLUCTUATIONS</font>
#
# denser
# varies from place to place these <font color="#FFFF00">DENSER</font>
#
# galaxies
# clusters of <font color="#FFFF00">GALAXIES</font> and super clusters
#
# galaxies
# and <font color="#FFFF00">GALAXIES</font> themselves these
#
# galaxies
# </font><font color="#FFFF00">GALAXIES</font><font> so this picture<font color="#E5E5E5"> really is our</font>
#
# imperfections
# old these tiny <font color="#FFFF00">IMPERFECTIONS</font> in the
#
# fledgling
# <font color="#FFFF00">FLEDGLING</font> universe would become galaxies
#
# galaxies
# <font color="#FFFF00">FLEDGLING</font> universe would become </font><font color="#FFFF00">GALAXIES</font><font>
#
# galaxies
# </font><font color="#FFFF00">GALAXIES</font><font> like<font color="#E5E5E5"> a milky way that contain a</font>
#
# swirling
# was filled with <font color="#FFFF00">SWIRLING</font> clouds of
#
# denser
# and bigger the gas clouds got <font color="#FFFF00">DENSER</font> and
#
# hotter
# <font color="#FFFF00">HOTTER</font> gravity pulled the gas clouds
#
# filaments
# together on <font color="#FFFF00">FILAMENTS</font> like beads on
#
# cosmic
# threads of a web <font color="#FFFF00">COSMIC</font> web where the
#
# filaments
# giant <font color="#FFFF00">FILAMENTS</font> formed large globs stars
#
# globs
# giant <font color="#FFFF00">FILAMENTS</font> formed large </font><font color="#FFFF00">GLOBS</font><font> stars
#
# galaxies
# and <font color="#FFFF00">GALAXIES</font> would grow as a universe
#
# evolved
# <font color="#FFFF00">EVOLVED</font> gases were able to condense into
#
# gases
# <font color="#FFFF00">EVOLVED</font> </font><font color="#FFFF00">GASES</font><font> were able to condense into
#
# condense
# <font color="#FFFF00">EVOLVED</font> </font><font color="#FFFF00">GASES</font><font> were able to </font><font color="#FFFF00">CONDENSE</font><font> into
#
# rotating
# star settle into a <font color="#FFFF00">ROTATING</font> disk that
#
# lated
# was<font color="#E5E5E5"> </font><font color="#FFFF00">LATED</font><font> to become a spiral galaxy like</font>
#
# spiral
# was<font color="#E5E5E5"> </font><font color="#FFFF00">LATED</font><font> to become a </font><font color="#FFFF00">SPIRAL</font><font> galaxy like</font>
#
# clumped
# <font color="#E5E5E5">hydrogen atoms </font><font color="#FFFF00">CLUMPED</font><font> together and</font>
#
# fusing
# heated up the atoms began <font color="#FFFF00">FUSING</font> and
#
# releasing
# </font><font color="#FFFF00">RELEASING</font><font> energy and the gas<font color="#E5E5E5"> cloud</font>
#
# brightly
# <font color="#E5E5E5">started to burn </font><font color="#FFFF00">BRIGHTLY</font><font> eventually a</font>
#
# ignited
# millions of stars <font color="#FFFF00">IGNITED</font> for the first
#
# cheesy
# would have been a <font color="#FFFF00">CHEESY</font> spectacular
#
# fireworks
# have really seen <font color="#FFFF00">FIREWORKS</font> individual
#
# burned
# the stars are born and <font color="#FFFF00">BURNED</font> themselves
#
# trillions
# <font color="#FFFF00">TRILLIONS</font> of times its original size
#
# newborn
# it was full<font color="#CCCCCC"> of </font><font color="#FFFF00">NEWBORN</font><font> stars made of</font>
#
# helium
# hydrogen and <font color="#FFFF00">HELIUM</font> these young stars
#
# unstable
# very<font color="#E5E5E5"> </font><font color="#FFFF00">UNSTABLE</font><font> but it was their</font>
#
# instability
# <font color="#FFFF00">INSTABILITY</font> that would make the universe
#
# astrophysicist
# came from the<font color="#E5E5E5"> british </font><font color="#FFFF00">ASTROPHYSICIST</font><font> sir</font>
#
# hoyle
# fred <font color="#FFFF00">HOYLE</font> one of the greatest
#
# astronomers
# <font color="#FFFF00">ASTRONOMERS</font> of the 20th century Hoyle
#
# Hoyle
# <font color="#FFFF00">ASTRONOMERS</font> of the 20th century </font><font color="#FFFF00">HOYLE</font><font>
#
# coined
# <font color="#E5E5E5">in a single explosion in fact he </font><font color="#FFFF00">COINED</font><font></font>
#
# derision
# the name big bang as a term of <font color="#FFFF00">DERISION</font>
#
# Hoyle
# <font color="#FFFF00">HOYLE</font> wanted to know where the elements
#
# heavier
# <font color="#FFFF00">HEAVIER</font> than hydrogen and helium came
#
# helium
# <font color="#FFFF00">HEAVIER</font> than hydrogen and </font><font color="#FFFF00">HELIUM</font><font> came
#
# acted
# from he figured<font color="#CCCCCC"> out</font><font color="#E5E5E5"> that stars </font><font color="#FFFF00">ACTED</font><font></font>
#
# reactors
# like nuclear <font color="#FFFF00">REACTORS</font> working a bit like
#
# analyzing
# </font><font color="#FFFF00">ANALYZING</font><font><font color="#CCCCCC"> the light from stars each</font>
#
# emits
# element <font color="#FFFF00">EMITS</font> a light at a particular
#
# emits
# sodium<font color="#E5E5E5"> street lamp it </font><font color="#FFFF00">EMITS</font><font> light of a</font>
#
# emits
# hydrogen which <font color="#FFFF00">EMITS</font> mainly red light we
#
# Hubble
# <font color="#E5E5E5">the</font><font color="#CCCCCC"> </font><font color="#FFFF00">HUBBLE</font><font> Space Telescope</font><font color="#E5E5E5"> to unravel</font>
#
# unravel
# <font color="#E5E5E5">the</font><font color="#CCCCCC"> </font><font color="#FFFF00">HUBBLE</font><font> Space Telescope</font><font color="#E5E5E5"> to </font><font color="#FFFF00">UNRAVEL</font><font></font>
#
# mysteries
# some of the <font color="#FFFF00">MYSTERIES</font> of our early
#
# Hubble
# the </font><font color="#FFFF00">HUBBLE</font><font><font color="#E5E5E5"> Space Telescope</font>
#
# hubbell
# <font color="#CCCCCC"></font><font color="#FFFF00">HUBBELL</font><font></font><font color="#E5E5E5"> promised scientists</font>
#
# unprecedented
# <font color="#FFFF00">UNPRECEDENTED</font> views of the young
#
# Hubble
# launched they discovered that <font color="#FFFF00">HUBBLE</font>'s
#
# distorted
# mirror was <font color="#FFFF00">DISTORTED</font> and saw everything
#
# astronaut
# repair man was <font color="#FFFF00">ASTRONAUT</font> Jeff Hoffman we
#
# Hoffman
# repair man was <font color="#FFFF00">ASTRONAUT</font> Jeff </font><font color="#FFFF00">HOFFMAN</font><font> we
#
# crippled
# to capture<font color="#CCCCCC"> the </font><font color="#FFFF00">CRIPPLED</font><font> telescope</font>
#
# unprecedented
# </font><font color="#FFFF00">UNPRECEDENTED</font><font><font color="#CCCCCC"> in the history of space</font>
#
# Hubble
# one thing about<font color="#E5E5E5"> working on </font><font color="#FFFF00">HUBBLE</font><font> that</font>
#
# astronauts
# <font color="#FFFF00">ASTRONAUTS</font> had to carry out fine
#
# spacesuit
# <font color="#CCCCCC"></font><font color="#FFFF00">SPACESUIT</font><font> your hands are encumbered by</font>
#
# encumbered
# <font color="#CCCCCC"></font><font color="#FFFF00">SPACESUIT</font><font> your hands are </font><font color="#FFFF00">ENCUMBERED</font><font> by</font>
#
# stiff
# thick </font><font color="#FFFF00">STIFF</font><font> gloves it's<font color="#E5E5E5"> sort of like</font>
#
# mittens
# working in ski <font color="#FFFF00">MITTENS</font> then it was quite
#
# Hoffman
# a challenge all went well<font color="#E5E5E5"> until </font><font color="#FFFF00">HOFFMAN</font><font></font>
#
# warped
# somewhat <font color="#FFFF00">WARPED</font> and it took a while for
#
# improvised
# the telescope using <font color="#FFFF00">IMPROVISED</font> tools
#
# stricken
# <font color="#FFFF00">STRICKEN</font> telescope cosmologists around
#
# cosmologists
# <font color="#FFFF00">STRICKEN</font> telescope </font><font color="#FFFF00">COSMOLOGISTS</font><font> around
#
# waited
# they </font><font color="#FFFF00">WAITED</font><font> to see<font color="#E5E5E5"> if the most expensive</font>
#
# Hubble
# the<font color="#E5E5E5"> first picture back and </font><font color="#FFFF00">HUBBLE</font><font> works</font>
#
# Hubble
# this is what <font color="#FFFF00">HUBBLE</font> saw the images were
#
# wildest
# beyond anyone's <font color="#FFFF00">WILDEST</font> dreams
#
# hubbell
# <font color="#CCCCCC"></font><font color="#FFFF00">HUBBELL</font><font> captured the final moments of a</font>
#
# explodes
# star's life when it <font color="#FFFF00">EXPLODES</font> and blows
#
# stellar
# </font><font color="#FFFF00">STELLAR</font><font> nurseries of<font color="#E5E5E5"> newborn stars</font>
#
# nurseries
# </font><font color="#FFFF00">STELLAR</font><font> </font><font color="#FFFF00">NURSERIES</font><font> of<font color="#E5E5E5"> newborn stars</font>
#
# newborn
# </font><font color="#FFFF00">STELLAR</font><font> </font><font color="#FFFF00">NURSERIES</font><font> of<font color="#E5E5E5"> </font><font color="#FFFF00">NEWBORN</font><font> stars</font>
#
# exploding
# <font color="#FFFF00">EXPLODING</font> into life billions of years
#
# pillars
# <font color="#E5E5E5">ago and</font><font color="#CCCCCC"> dark </font><font color="#FFFF00">PILLARS</font><font> of cosmic dust</font>
#
# cosmic
# <font color="#E5E5E5">ago and</font><font color="#CCCCCC"> dark </font><font color="#FFFF00">PILLARS</font><font> of </font><font color="#FFFF00">COSMIC</font><font> dust</font>
#
# spawn
# ready to <font color="#FFFF00">SPAWN</font> a new generation of stars
#
# surpass
# and<font color="#E5E5E5"> planets</font><font color="#CCCCCC"> I guess it's hard to </font><font color="#FFFF00">SURPASS</font><font></font>
#
# pillars
# the famous </font><font color="#FFFF00">PILLARS</font><font> of creation<font color="#CCCCCC"> in the</font>
#
# Nebula
# <font color="#E5E5E5">Eagle </font><font color="#FFFF00">NEBULA</font><font> where you actually see the</font>
#
# goose
# <font color="#CCCCCC">kind of</font><font color="#E5E5E5"> get </font><font color="#FFFF00">GOOSE</font><font> bumps when I look at</font>
#
# bumps
# <font color="#CCCCCC">kind of</font><font color="#E5E5E5"> get </font><font color="#FFFF00">GOOSE</font><font> </font><font color="#FFFF00">BUMPS</font><font> when I look at</font>
#
# Hubble
# it but <font color="#FFFF00">HUBBLE</font>'s true moment of glory was
#
# emerged
# space what <font color="#FFFF00">EMERGED</font> was the Deep Field
#
# tapestry
# image a <font color="#FFFF00">TAPESTRY</font> of distant galaxies
#
# galaxies
# image a <font color="#FFFF00">TAPESTRY</font> of distant </font><font color="#FFFF00">GALAXIES</font><font>
#
# Hubble
# </font><font color="#FFFF00">HUBBLE</font><font> was looking back in time<font color="#E5E5E5"> to some</font>
#
# galaxies
# of the first <font color="#FFFF00">GALAXIES</font> and stars created
#
# galaxies
# it revealed thousands of <font color="#FFFF00">GALAXIES</font> that
#
# richer
# </font><font color="#FFFF00">RICHER</font><font><font color="#E5E5E5"> after the Hubble Deep Field it</font>
#
# Hubble
# </font><font color="#FFFF00">RICHER</font><font><font color="#E5E5E5"> after the </font><font color="#FFFF00">HUBBLE</font><font> Deep Field it</font>
#
# faint
# showed for the first time <font color="#FFFF00">FAINT</font> images
#
# galaxies
# of </font><font color="#FFFF00">GALAXIES</font><font> form<font color="#E5E5E5"> just a billion years</font>
#
# galaxies
# these early </font><font color="#FFFF00">GALAXIES</font><font> had already<font color="#E5E5E5"> created</font>
#
# heavier
# elements <font color="#FFFF00">HEAVIER</font> than hydrogen and
#
# helium
# </font><font color="#FFFF00">HELIUM</font><font> sir<font color="#E5E5E5"> Fred Hoyle may have been</font>
#
# Hoyle
# </font><font color="#FFFF00">HELIUM</font><font> sir<font color="#E5E5E5"> Fred </font><font color="#FFFF00">HOYLE</font><font> may have been</font>
#
# acted
# <font color="#CCCCCC">stars the early stars </font><font color="#FFFF00">ACTED</font><font> like giant</font>
#
# thermo
# <font color="#FFFF00">THERMO</font> nuclear reactors creating new
#
# reactors
# <font color="#FFFF00">THERMO</font> nuclear </font><font color="#FFFF00">REACTORS</font><font> creating new
#
# sequentially
# <font color="#FFFF00">SEQUENTIALLY</font> added to the vehicle until
#
# heavier
# fuse to form new <font color="#FFFF00">HEAVIER</font> elements one
#
# helium
# after the<font color="#CCCCCC"> other three </font><font color="#FFFF00">HELIUM</font><font> nuclei</font>
#
# nuclei
# after the<font color="#CCCCCC"> other three </font><font color="#FFFF00">HELIUM</font><font> </font><font color="#FFFF00">NUCLEI</font><font></font>
#
# nuclei
# combined to form carbon to carbon <font color="#FFFF00">NUCLEI</font>
#
# magnesium
# fuse to form <font color="#FFFF00">MAGNESIUM</font> <font color="#FFFF00">MAGNESIUM</font> to form
#
# magnesium
# fuse to form <font color="#FFFF00">MAGNESIUM</font> <font color="#FFFF00">MAGNESIUM</font> to form
#
# fused
# <font color="#FFFF00">FUSED</font> to form iron iron is a very
#
# protons
# <font color="#E5E5E5">special animal the </font><font color="#FFFF00">PROTONS</font><font> and neutrons</font>
#
# neutrons
# <font color="#E5E5E5">special animal the </font><font color="#FFFF00">PROTONS</font><font> and </font><font color="#FFFF00">NEUTRONS</font><font></font>
#
# nucleus
# inside its </font><font color="#FFFF00">NUCLEUS</font><font> are<font color="#E5E5E5"> very tightly</font>
#
# tightly
# inside its </font><font color="#FFFF00">NUCLEUS</font><font> are<font color="#E5E5E5"> very </font><font color="#FFFF00">TIGHTLY</font><font></font>
#
# heavier
# get it to fuse into <font color="#FFFF00">HEAVIER</font> elements it
#
# resolute
# </font><font color="#FFFF00">RESOLUTE</font><font> listes iron it was the end<font color="#E5E5E5"> of</font>
#
# listes
# </font><font color="#FFFF00">RESOLUTE</font><font> </font><font color="#FFFF00">LISTES</font><font> iron it was the end<font color="#E5E5E5"> of</font>
#
# chromium
# ingredients like <font color="#FFFF00">CHROMIUM</font> for our car
#
# fender
# <font color="#FFFF00">FENDER</font> and some metals like zinc that
#
# heavier
# elements </font><font color="#FFFF00">HEAVIER</font><font> than iron to<font color="#CCCCCC"> make the</font>
#
# jigsaw
# universe <font color="#FFFF00">JIGSAW</font> would take some of the
#
# celebrated
# our<font color="#E5E5E5"> universe has already </font><font color="#FFFF00">CELEBRATED</font><font> its</font>
#
# chromium
# <font color="#CCCCCC">missing heavy metals like </font><font color="#FFFF00">CHROMIUM</font><font></font><font color="#E5E5E5"> and</font>
#
# conjures
# </font><font color="#FFFF00">CONJURES</font><font> up the<font color="#E5E5E5"> most amazing phenomena</font>
#
# exploding
# since the Big Bang massive <font color="#FFFF00">EXPLODING</font>
#
# supernovas
# stars called <font color="#FFFF00">SUPERNOVAS</font> when the giant
#
# collapsed
# out of fuel they </font><font color="#FFFF00">COLLAPSED</font><font> in<font color="#E5E5E5"> on</font>
#
# heavier
# fuse elements<font color="#E5E5E5"> even </font><font color="#FFFF00">HEAVIER</font><font> than iron and</font>
#
# restart
# <font color="#FFFF00">RESTART</font> the element production line Tony
#
# zacapa
# met<font color="#CCCCCC"> </font><font color="#FFFF00">ZACAPA</font><font> from Oak Ridge National</font>
#
# exploding
# <font color="#E5E5E5">without </font><font color="#FFFF00">EXPLODING</font><font> stars life itself</font>
#
# supernova
# for core collapse <font color="#FFFF00">SUPERNOVA</font> events they
#
# supernovas
# <font color="#CCCCCC">and biggest </font><font color="#FFFF00">SUPERNOVAS</font><font> closest to our</font>
#
# hemisphere
# </font><font color="#FFFF00">HEMISPHERE</font><font><font color="#E5E5E5"> in 1987 when a supernova like</font>
#
# supernova
# </font><font color="#FFFF00">HEMISPHERE</font><font><font color="#E5E5E5"> in 1987 when a </font><font color="#FFFF00">SUPERNOVA</font><font> like</font>
#
# explodes
# 1987a <font color="#FFFF00">EXPLODES</font> it emits light containing
#
# emits
# 1987a <font color="#FFFF00">EXPLODES</font> it </font><font color="#FFFF00">EMITS</font><font> light containing
#
# forged
# are being <font color="#FFFF00">FORGED</font> inside the exploding
#
# exploding
# are being <font color="#FFFF00">FORGED</font> inside the </font><font color="#FFFF00">EXPLODING</font><font>
#
# astrophysics
# </font><font color="#FFFF00">ASTROPHYSICS</font><font> group at<font color="#CCCCCC"> oakridge then</font>
#
# oakridge
# </font><font color="#FFFF00">ASTROPHYSICS</font><font> group at<font color="#CCCCCC"> </font><font color="#FFFF00">OAKRIDGE</font><font> then</font>
#
# recreates
# <font color="#FFFF00">RECREATES</font> these events inside his own
#
# accelerates
# he <font color="#FFFF00">ACCELERATES</font> and smashes individual
#
# smashes
# he <font color="#FFFF00">ACCELERATES</font> and </font><font color="#FFFF00">SMASHES</font><font> individual
#
# supernova
# inside a </font><font color="#FFFF00">SUPERNOVA</font><font><font color="#CCCCCC"> a sub atomic nuclei</font>
#
# nuclei
# inside a </font><font color="#FFFF00">SUPERNOVA</font><font><font color="#CCCCCC"> a sub atomic </font><font color="#FFFF00">NUCLEI</font><font></font>
#
# heaviest
# in the formation<font color="#CCCCCC"> of</font><font color="#E5E5E5"> the </font><font color="#FFFF00">HEAVIEST</font><font></font>
#
# nuclei
# exactly how fast these <font color="#FFFF00">NUCLEI</font> will fuse
#
# exploding
# the fuse inside <font color="#FFFF00">EXPLODING</font> stones when
#
# collide
# the<font color="#E5E5E5"> particles </font><font color="#FFFF00">COLLIDE</font><font> inside the</font>
#
# accelerator
# <font color="#FFFF00">ACCELERATOR</font> they generate enormous
#
# exploding
# and we believe that <font color="#FFFF00">EXPLODING</font> stars are
#
# heavier
# just right to form elements much <font color="#FFFF00">HEAVIER</font>
#
# zacapa
# <font color="#CCCCCC"></font><font color="#FFFF00">ZACAPA</font><font> has created a model of how these</font>
#
# exploding
# massive <font color="#FFFF00">EXPLODING</font> stars turn into heavy
#
# factories
# element <font color="#FFFF00">FACTORIES</font>
#
# evolved
# massive stars have </font><font color="#FFFF00">EVOLVED</font><font><font color="#E5E5E5"> to an onion</font>
#
# successively
# the iron core are layers of <font color="#FFFF00">SUCCESSIVELY</font>
#
# hotter
# degrees nearly<font color="#E5E5E5"> 300</font><font color="#CCCCCC"> times </font><font color="#FFFF00">HOTTER</font><font></font><font color="#E5E5E5"> than the</font>
#
# sunk
# atoms that have <font color="#FFFF00">SUNK</font> to the Stars core
#
# torn
# are </font><font color="#FFFF00">TORN</font><font> apart the core<font color="#CCCCCC"> destabilizes the</font>
#
# destabilizes
# are </font><font color="#FFFF00">TORN</font><font> apart the core<font color="#CCCCCC"> </font><font color="#FFFF00">DESTABILIZES</font><font> the</font>
#
# densities
# proceeds to very<font color="#E5E5E5"> very high </font><font color="#FFFF00">DENSITIES</font><font> the</font>
#
# crunches
# size of the earth <font color="#FFFF00">CRUNCHES</font> down nearly
#
# centimeter
# one were to take one cubic <font color="#FFFF00">CENTIMETER</font> of
#
# weigh
# dense that it would <font color="#FFFF00">WEIGH</font> as much as the
#
# shockwave
# massive <font color="#FFFF00">SHOCKWAVE</font> the <font color="#FFFF00">SHOCKWAVE</font> hurdles
#
# shockwave
# massive <font color="#FFFF00">SHOCKWAVE</font> the <font color="#FFFF00">SHOCKWAVE</font> hurdles
#
# hurdles
# massive <font color="#FFFF00">SHOCKWAVE</font> the <font color="#FFFF00">SHOCKWAVE</font> </font><font color="#FFFF00">HURDLES</font><font>
#
# smashing
# out <font color="#FFFF00">SMASHING</font> through the different skins
#
# restarts
# <font color="#E5E5E5"></font><font color="#FFFF00">RESTARTS</font><font> the element production line</font>
#
# smashed
# atoms are </font><font color="#FFFF00">SMASHED</font><font> together to make<font color="#CCCCCC"> brand</font>
#
# heavier
# <font color="#CCCCCC">new </font><font color="#FFFF00">HEAVIER</font><font> elements all </font><font color="#FFFF00">HEAVIER</font><font> than</font>
#
# heavier
# <font color="#CCCCCC">new </font><font color="#FFFF00">HEAVIER</font><font> elements all </font><font color="#FFFF00">HEAVIER</font><font> than</font>
#
# explodes
# iron then the star </font><font color="#FFFF00">EXPLODES</font><font> and<font color="#CCCCCC"> the</font>
#
# shrapnel
# shock wave pushes the <font color="#FFFF00">SHRAPNEL</font> like
#
# debris
# </font><font color="#FFFF00">DEBRIS</font><font> outward further and<font color="#CCCCCC"> further into</font>
#
# outward
# </font><font color="#FFFF00">DEBRIS</font><font> </font><font color="#FFFF00">OUTWARD</font><font> further and<font color="#CCCCCC"> further into</font>
#
# astonishing
# not be here<font color="#CCCCCC"> today these </font><font color="#FFFF00">ASTONISHING</font><font></font>
#
# Hubble
# images taken by the </font><font color="#FFFF00">HUBBLE</font><font><font color="#E5E5E5"> Space</font>
#
# aftermath
# Telescope show the <font color="#FFFF00">AFTERMATH</font> of these
#
# nebulae
# giant explosions <font color="#FFFF00">NEBULAE</font> giant clouds of
#
# debris
# <font color="#FFFF00">DEBRIS</font> thrown off by exploding stars
#
# exploding
# <font color="#FFFF00">DEBRIS</font> thrown off by </font><font color="#FFFF00">EXPLODING</font><font> stars
#
# swirling
# <font color="#FFFF00">SWIRLING</font> inside our big new atoms gold
#
# supernovas
# <font color="#E5E5E5">silver zinc and lead without </font><font color="#FFFF00">SUPERNOVAS</font><font></font>
#
# dull
# our world would<font color="#E5E5E5"> be a</font><font color="#CCCCCC"> very </font><font color="#FFFF00">DULL</font><font> place and</font>
#
# lifeless
# possibly <font color="#FFFF00">LIFELESS</font>
#
# exploding
# </font><font color="#FFFF00">EXPLODING</font><font> stars those<font color="#E5E5E5"> 200 million stars</font>
#
# exploded
# that </font><font color="#FFFF00">EXPLODED</font><font> so we could<font color="#E5E5E5"> be here today</font>
#
# supernova
# it weren't<font color="#E5E5E5"> for those </font><font color="#FFFF00">SUPERNOVA</font><font></font>
#
# bling
# explosions there wouldn't<font color="#E5E5E5"> be any </font><font color="#FFFF00">BLING</font><font></font>
#
# galaxies
# billions of<font color="#E5E5E5"> </font><font color="#FFFF00">GALAXIES</font><font> and uncountable</font>
#
# uncountable
# billions of<font color="#E5E5E5"> </font><font color="#FFFF00">GALAXIES</font><font> and </font><font color="#FFFF00">UNCOUNTABLE</font><font></font>
#
# accumulate
# </font><font color="#FFFF00">ACCUMULATE</font><font> it's full<font color="#E5E5E5"> of the rich debris</font>
#
# debris
# </font><font color="#FFFF00">ACCUMULATE</font><font> it's full<font color="#E5E5E5"> of the rich </font><font color="#FFFF00">DEBRIS</font><font></font>
#
# supernovas
# <font color="#FFFF00">SUPERNOVAS</font> and when it reaches a
#
# brightly
# critical mass it begins to<font color="#E5E5E5"> burn </font><font color="#FFFF00">BRIGHTLY</font><font></font>
#
# swirling
# <font color="#FFFF00">SWIRLING</font> debris in orbit around the new
#
# debris
# <font color="#FFFF00">SWIRLING</font> </font><font color="#FFFF00">DEBRIS</font><font> in orbit around the new
#
# wrinkle
# </font><font color="#FFFF00">WRINKLE</font><font><font color="#E5E5E5"> I pulled together by gravity the</font>
#
# clumps
# <font color="#FFFF00">CLUMPS</font> of dust and gas become bigger and
#
# canopy
# generates a protective <font color="#FFFF00">CANOPY</font> of gas the
#
# eons
# <font color="#E5E5E5">single cells at first but as the </font><font color="#FFFF00">EONS</font><font></font>
#
# evolved
# pass those tiny single cells<font color="#CCCCCC"> </font><font color="#FFFF00">EVOLVED</font><font></font>
#
# disassociate
# humans we tend to <font color="#FFFF00">DISASSOCIATE</font> ourselves
#
# cosmos
# the </font><font color="#FFFF00">COSMOS</font><font> and so when we<font color="#E5E5E5"> talk about the</font>
#
# Krauss
# like </font><font color="#FFFF00">KRAUSS</font><font><font color="#CCCCCC"> believe they now know the</font>
#
# amazed
# </font><font color="#FFFF00">AMAZED</font><font> but this is not the<font color="#CCCCCC"> final chapter</font>
#
# evolving
# </font><font color="#FFFF00">EVOLVING</font><font> scientists have<font color="#E5E5E5"> come up with</font>
#
# whimper
# end with a bang or<font color="#E5E5E5"> a </font><font color="#FFFF00">WHIMPER</font><font> or</font>
#
# pinpoint
# dense </font><font color="#FFFF00">PINPOINT</font><font> known as the Big<font color="#E5E5E5"> Crunch</font>
#
# Crunch
# dense </font><font color="#FFFF00">PINPOINT</font><font> known as the Big<font color="#E5E5E5"> </font><font color="#FFFF00">CRUNCH</font><font></font>
#
# astrophysicists
# down<font color="#CCCCCC"> </font><font color="#FFFF00">ASTROPHYSICISTS</font><font> Saul Perlmutter</font>
#
# Saul
# down<font color="#CCCCCC"> </font><font color="#FFFF00">ASTROPHYSICISTS</font><font> </font><font color="#FFFF00">SAUL</font><font> Perlmutter</font>
#
# Perlmutter
# down<font color="#CCCCCC"> </font><font color="#FFFF00">ASTROPHYSICISTS</font><font> </font><font color="#FFFF00">SAUL</font><font> </font><font color="#FFFF00">PERLMUTTER</font><font></font>
#
# beacons
# <font color="#E5E5E5">finding </font><font color="#FFFF00">BEACONS</font><font> in space exploding stars</font>
#
# exploding
# <font color="#E5E5E5">finding </font><font color="#FFFF00">BEACONS</font><font> in space </font><font color="#FFFF00">EXPLODING</font><font> stars</font>
#
# supernovas
# called type 1a <font color="#FFFF00">SUPERNOVAS</font> if you have
#
# exploding
# enough of these <font color="#FFFF00">EXPLODING</font> stars these as
#
# supernova
# the<font color="#E5E5E5"> </font><font color="#FFFF00">SUPERNOVA</font><font> that</font><font color="#CCCCCC"> you've measured their</font>
#
# fainter
# <font color="#FFFF00">FAINTER</font> and <font color="#FFFF00">FAINTER</font> and <font color="#FFFF00">FAINTER</font> must be
#
# fainter
# <font color="#FFFF00">FAINTER</font> and <font color="#FFFF00">FAINTER</font> and <font color="#FFFF00">FAINTER</font> must be
#
# fainter
# <font color="#FFFF00">FAINTER</font> and <font color="#FFFF00">FAINTER</font> and <font color="#FFFF00">FAINTER</font> must be
#
# brighter
# </font><font color="#FFFF00">BRIGHTER</font><font><font color="#CCCCCC"> there're more nearby some that</font>
#
# fainter
# are a little bit<font color="#E5E5E5"> </font><font color="#FFFF00">FAINTER</font><font> so they're</font>
#
# faint
# very <font color="#FFFF00">FAINT</font> so they're very far away type
#
# supernovas
# 1a <font color="#FFFF00">SUPERNOVAS</font> are similar to the
#
# supernovas
# <font color="#FFFF00">SUPERNOVAS</font> that created the heavy
#
# gravitational
# their <font color="#FFFF00">GRAVITATIONAL</font> attraction one is
#
# shriveled
# <font color="#FFFF00">SHRIVELED</font> and super dense glowing with
#
# glowing
# <font color="#FFFF00">SHRIVELED</font> and super dense </font><font color="#FFFF00">GLOWING</font><font> with
#
# dwarf
# white heat a white <font color="#FFFF00">DWARF</font> the other star
#
# bloated
# has </font><font color="#FFFF00">BLOATED</font><font> to an enormous<font color="#E5E5E5"> size it's a</font>
#
# dwarf
# white <font color="#FFFF00">DWARF</font> sucks gas from its companion
#
# dwarf
# <font color="#FFFF00">DWARF</font> crumples collapses then explodes
#
# crumples
# <font color="#FFFF00">DWARF</font> </font><font color="#FFFF00">CRUMPLES</font><font> collapses then explodes
#
# explodes
# <font color="#FFFF00">DWARF</font> </font><font color="#FFFF00">CRUMPLES</font><font> collapses then </font><font color="#FFFF00">EXPLODES</font><font>
#
# releasing
# <font color="#FFFF00">RELEASING</font> a blinding burst of energy
#
# blinding
# <font color="#FFFF00">RELEASING</font> a </font><font color="#FFFF00">BLINDING</font><font> burst of energy
#
# supernova
# every type 1a <font color="#FFFF00">SUPERNOVA</font> explodes at the
#
# explodes
# every type 1a <font color="#FFFF00">SUPERNOVA</font> </font><font color="#FFFF00">EXPLODES</font><font> at the
#
# tipping
# same </font><font color="#FFFF00">TIPPING</font><font> point and<font color="#E5E5E5"> so are equally</font>
#
# Perlmutter
# distances of<font color="#CCCCCC"> the universe </font><font color="#FFFF00">PERLMUTTER</font><font></font>
#
# supernovas
# </font><font color="#FFFF00">SUPERNOVAS</font><font> and<font color="#E5E5E5"> then measure how fast</font>
#
# Hubble
# <font color="#E5E5E5">advanced cameras on the </font><font color="#FFFF00">HUBBLE</font><font></font><font color="#CCCCCC"> Space</font>
#
# supernovas
# <font color="#FFFF00">SUPERNOVAS</font> once Hubble has detected a
#
# Hubble
# <font color="#FFFF00">SUPERNOVAS</font> once </font><font color="#FFFF00">HUBBLE</font><font> has detected a
#
# Lydman
# <font color="#FFFF00">LYDMAN</font> at the VLT analyzes the object to
#
# supernova
# a type<font color="#E5E5E5"> 1a </font><font color="#FFFF00">SUPERNOVA</font><font> this object</font><font color="#CCCCCC"> is is a</font>
#
# supernova
# believe is a distant <font color="#FFFF00">SUPERNOVA</font> the next
#
# supernova
# of <font color="#FFFF00">SUPERNOVA</font> this is the VLT breaks down
#
# fingerprint
# the very characteristic <font color="#FFFF00">FINGERPRINT</font> that
#
# supernova
# a type 1a<font color="#E5E5E5"> </font><font color="#FFFF00">SUPERNOVA</font><font></font>
#
# emitted
# the light <font color="#FFFF00">EMITTED</font> from this particular
#
# supernova
# <font color="#E5E5E5"></font><font color="#FFFF00">SUPERNOVA</font><font> reveals that it's a type 1a</font>
#
# Lydman
# <font color="#FFFF00">LYDMAN</font> can now calculate how far away
#
# supernova
# this <font color="#FFFF00">SUPERNOVA</font> is the <font color="#FFFF00">SUPERNOVA</font> exploded
#
# supernova
# this <font color="#FFFF00">SUPERNOVA</font> is the <font color="#FFFF00">SUPERNOVA</font> exploded
#
# exploded
# this <font color="#FFFF00">SUPERNOVA</font> is the <font color="#FFFF00">SUPERNOVA</font> </font><font color="#FFFF00">EXPLODED</font><font>
#
# supernovas
# <font color="#FFFF00">SUPERNOVAS</font> stretched over space and time
#
# stretched
# <font color="#FFFF00">SUPERNOVAS</font> </font><font color="#FFFF00">STRETCHED</font><font> over space and time
#
# Perlmutter
# <font color="#CCCCCC"></font><font color="#FFFF00">PERLMUTTER</font><font> can calculate whether the</font>
#
# halt
# to a </font><font color="#FFFF00">HALT</font><font> and<font color="#E5E5E5"> in fact it wasn't slowing</font>
#
# Perlmutter
# speeding up its expansion <font color="#FFFF00">PERLMUTTER</font>'s
#
# astounding
# <font color="#FFFF00">ASTOUNDING</font> discovery means that the
#
# grind
# universe will<font color="#E5E5E5"> not </font><font color="#FFFF00">GRIND</font><font> to a halt then</font>
#
# halt
# universe will<font color="#E5E5E5"> not </font><font color="#FFFF00">GRIND</font><font> to a </font><font color="#FFFF00">HALT</font><font> then</font>
#
# crunch
# </font><font color="#FFFF00">CRUNCH</font><font> back down<font color="#E5E5E5"> into a pinhead of super</font>
#
# pinhead
# </font><font color="#FFFF00">CRUNCH</font><font> back down<font color="#E5E5E5"> into a </font><font color="#FFFF00">PINHEAD</font><font> of super</font>
#
# accelerate
# universe will <font color="#FFFF00">ACCELERATE</font> it ever faster
#
# ripped
# everything will get <font color="#FFFF00">RIPPED</font> apart not
#
# galaxies
# just <font color="#FFFF00">GALAXIES</font> but eventually matter the
#
# ripped
# would get <font color="#FFFF00">RIPPED</font> apart
#
# burned
# long after<font color="#CCCCCC"> our</font><font color="#E5E5E5"> son has </font><font color="#FFFF00">BURNED</font><font> out a</font>
#
# galaxies
# <font color="#FFFF00">GALAXIES</font> will pull apart the universe
#
# dwarfs
# become white or brown <font color="#FFFF00">DWARFS</font> others will
#
# neutron
# collapse into <font color="#FFFF00">NEUTRON</font> stars or black
#
# trillions
# holes then thousands<font color="#E5E5E5"> of </font><font color="#FFFF00">TRILLIONS</font><font> of</font>
#
# evaporate
# <font color="#E5E5E5">holes will </font><font color="#FFFF00">EVAPORATE</font><font> an all matter will</font>
#
# decay
# <font color="#FFFF00">DECAY</font> to its basic ingredients atoms
#
# protons
# will fall apart and even <font color="#FFFF00">PROTONS</font> the
#
# decay
# building blocks of atoms will <font color="#FFFF00">DECAY</font>
#
# dismal
# </font><font color="#FFFF00">DISMAL</font><font> one where the<font color="#E5E5E5"> universe becomes</font>
#
# galaxies
# continues to expand and<font color="#CCCCCC"> the</font><font color="#E5E5E5"> </font><font color="#FFFF00">GALAXIES</font><font></font>
#
# galaxies
# </font><font color="#FFFF00">GALAXIES</font><font> will be moving<font color="#E5E5E5"> away from us</font>
#
# disappear
# </font><font color="#FFFF00">DISAPPEAR</font><font> from<font color="#CCCCCC"> the night skies</font>
#
# skies
# </font><font color="#FFFF00">DISAPPEAR</font><font> from<font color="#CCCCCC"> the night </font><font color="#FFFF00">SKIES</font><font></font>
#
# lifeless
# <font color="#FFFF00">LIFELESS</font> space

# %%
inputFile=inputFile.replace('.srt','(processed).srt')
output=open(inputFile,"w")
#output.write(subtitle.lower())
for eachLine in subtitle:
    output.write(eachLine)
output.close()

# %% [markdown]
# # 3rd project for the same
# ## get sentences for above words from an api

# %%
import json
import requests
